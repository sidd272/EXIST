# %%
import pandas as pd
import json

# %%
df=pd.read_json('training/EXIST2023_training.json')
df=df.transpose()
spanish = df.loc[df['lang']=='es']

# %%
english = df.loc[df['lang']=='en']

# %%
sexist=df.loc[df['labels_task1'].apply(lambda x:x.count('YES'))>3]

# %%
non_sexist=df.loc[df['labels_task1'].apply(lambda x:x.count('YES'))<3]

# %%
sexist_en=sexist.loc[sexist.lang=='en']
sexist_en
# Out:
#        id_EXIST lang                                              tweet  \
# 200002   200002   en  Writing a uni essay in my local pub with a cof...
# 200003   200003   en  @UniversalORL it is 2021 not 1921. I dont appr...
# 200006   200006   en  According to a customer I have plenty of time ...
# 200007   200007   en  So only 'blokes' drink beer? Sorry, but if you...
# 200011   200011   en  #EverydaySexism means women usually end up in ...
# ...         ...  ...                                                ...
# 203256   203256   en  idk why y’all bitches think having half your a...
# 203257   203257   en  This has been a part of an experiment with @Wo...
# 203258   203258   en  "Take me already" "Not yet. You gotta be ready...
# 203259   203259   en  @clintneedcoffee why do you look like a whore?...
# 203260   203260   en  ik when mandy says “you look like a whore” i l...
#
#        number_annotators                                         annotators  \
# 200002                 6  [Annotator_391, Annotator_392, Annotator_393, ...
# 200003                 6  [Annotator_397, Annotator_398, Annotator_399, ...
# 200006                 6  [Annotator_409, Annotator_410, Annotator_411, ...
# 200007                 6  [Annotator_415, Annotator_416, Annotator_417, ...
# 200011                 6  [Annotator_437, Annotator_438, Annotator_439, ...
# ...                  ...                                                ...
# 203256                 6  [Annotator_478, Annotator_479, Annotator_480, ...
# 203257                 6  [Annotator_668, Annotator_669, Annotator_670, ...
# 203258                 6  [Annotator_467, Annotator_468, Annotator_469, ...
# 203259                 6  [Annotator_674, Annotator_675, Annotator_676, ...
# 203260                 6  [Annotator_473, Annotator_474, Annotator_475, ...
#
#          gender_annotators                          age_annotators  \
# 200002  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 200003  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 200006  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 200007  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 200011  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# ...                    ...                                     ...
# 203256  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203257  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203258  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203259  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203260  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
#
#                           labels_task1  \
# 200002   [YES, YES, YES, NO, YES, YES]
# 200003    [YES, YES, NO, YES, NO, YES]
# 200006  [YES, YES, YES, YES, YES, YES]
# 200007  [YES, YES, YES, YES, YES, YES]
# 200011  [YES, YES, YES, YES, YES, YES]
# ...                                ...
# 203256  [YES, YES, YES, YES, YES, YES]
# 203257  [YES, YES, YES, YES, YES, YES]
# 203258    [NO, YES, NO, YES, YES, YES]
# 203259  [YES, YES, YES, YES, YES, YES]
# 203260   [YES, YES, YES, NO, YES, YES]
#
#                                              labels_task2  \
# 200002  [REPORTED, DIRECT, REPORTED, -, REPORTED, REPO...
# 200003  [REPORTED, REPORTED, -, REPORTED, -, JUDGEMENTAL]
# 200006  [REPORTED, REPORTED, REPORTED, REPORTED, REPOR...
# 200007  [JUDGEMENTAL, REPORTED, REPORTED, DIRECT, DIRE...
# 200011  [REPORTED, JUDGEMENTAL, JUDGEMENTAL, JUDGEMENT...
# ...                                                   ...
# 203256  [JUDGEMENTAL, DIRECT, DIRECT, DIRECT, JUDGEMEN...
# 203257  [JUDGEMENTAL, REPORTED, JUDGEMENTAL, DIRECT, J...
# 203258        [-, DIRECT, -, DIRECT, DIRECT, JUDGEMENTAL]
# 203259  [DIRECT, DIRECT, DIRECT, DIRECT, JUDGEMENTAL, ...
# 203260  [DIRECT, DIRECT, REPORTED, -, JUDGEMENTAL, REP...
#
#                                              labels_task3     split
# 200002  [[STEREOTYPING-DOMINANCE, OBJECTIFICATION, MIS...  TRAIN_EN
# 200003  [[OBJECTIFICATION, SEXUAL-VIOLENCE], [STEREOTY...  TRAIN_EN
# 200006  [[STEREOTYPING-DOMINANCE, OBJECTIFICATION], [S...  TRAIN_EN
# 200007  [[STEREOTYPING-DOMINANCE], [STEREOTYPING-DOMIN...  TRAIN_EN
# 200011  [[IDEOLOGICAL-INEQUALITY, STEREOTYPING-DOMINAN...  TRAIN_EN
# ...                                                   ...       ...
# 203256  [[OBJECTIFICATION], [STEREOTYPING-DOMINANCE, S...  TRAIN_EN
# 203257  [[OBJECTIFICATION], [OBJECTIFICATION], [OBJECT...  TRAIN_EN
# 203258  [[-], [OBJECTIFICATION], [-], [SEXUAL-VIOLENCE...  TRAIN_EN
# 203259  [[OBJECTIFICATION, SEXUAL-VIOLENCE, MISOGYNY-N...  TRAIN_EN
# 203260  [[STEREOTYPING-DOMINANCE], [OBJECTIFICATION], ...  TRAIN_EN
#
# [1137 rows x 11 columns]

# %%
sexist_es=sexist.loc[sexist.lang=='es']
sexist_es
# Out:
#        id_EXIST lang                                              tweet  \
# 100001   100001   es  @TheChiflis Ignora al otro, es un capullo.El p...
# 100005   100005   es  @novadragon21 @icep4ck @TvDannyZ Entonces como...
# 100008   100008   es  @BestKabest Esta gringa sigue llorando por el ...
# 100028   100028   es  @ShahidForChange @TeamPelosi Quiet, sexist ^%$...
# 100036   100036   es          @Harassed_girl loca d mierda en k momento
# ...         ...  ...                                                ...
# 103655   103655   es  que envidia me dan las dos zorras estas, yo de...
# 103656   103656   es  Los hombres sieeeempre dicen que si fueran muj...
# 103657   103657   es  @dat_mauro Estas zorras qls siempre preocupada...
# 103658   103658   es  A pesar de que convenga que las Zorras jueguen...
# 103660   103660   es  @soyunamedusilla Aaaaaaa ¿quién te manda socia...
#
#        number_annotators                                         annotators  \
# 100001                 6  [Annotator_1, Annotator_2, Annotator_3, Annota...
# 100005                 6  [Annotator_19, Annotator_20, Annotator_21, Ann...
# 100008                 6  [Annotator_25, Annotator_26, Annotator_27, Ann...
# 100028                 6  [Annotator_109, Annotator_110, Annotator_111, ...
# 100036                 6  [Annotator_115, Annotator_116, Annotator_117, ...
# ...                  ...                                                ...
# 103655                 6  [Annotator_295, Annotator_296, Annotator_297, ...
# 103656                 6  [Annotator_265, Annotator_266, Annotator_267, ...
# 103657                 6  [Annotator_223, Annotator_224, Annotator_225, ...
# 103658                 6  [Annotator_1, Annotator_2, Annotator_3, Annota...
# 103660                 6  [Annotator_13, Annotator_14, Annotator_15, Ann...
#
#          gender_annotators                          age_annotators  \
# 100001  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100005  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100008  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100028  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100036  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# ...                    ...                                     ...
# 103655  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 103656  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 103657  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 103658  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 103660  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
#
#                           labels_task1  \
# 100001   [YES, YES, NO, YES, YES, YES]
# 100005    [YES, NO, YES, NO, YES, YES]
# 100008  [YES, YES, YES, YES, YES, YES]
# 100028    [YES, NO, NO, YES, YES, YES]
# 100036   [YES, YES, YES, YES, YES, NO]
# ...                                ...
# 103655   [YES, YES, YES, NO, YES, YES]
# 103656   [YES, YES, YES, YES, NO, YES]
# 103657   [YES, YES, NO, YES, YES, YES]
# 103658   [NO, YES, YES, YES, YES, YES]
# 103660    [YES, NO, YES, YES, YES, NO]
#
#                                              labels_task2  \
# 100001  [REPORTED, JUDGEMENTAL, -, REPORTED, JUDGEMENT...
# 100005  [REPORTED, -, JUDGEMENTAL, -, JUDGEMENTAL, DIR...
# 100008  [DIRECT, DIRECT, DIRECT, JUDGEMENTAL, DIRECT, ...
# 100028        [JUDGEMENTAL, -, -, DIRECT, DIRECT, DIRECT]
# 100036        [DIRECT, DIRECT, DIRECT, DIRECT, DIRECT, -]
# ...                                                   ...
# 103655   [JUDGEMENTAL, DIRECT, DIRECT, -, DIRECT, DIRECT]
# 103656  [JUDGEMENTAL, JUDGEMENTAL, DIRECT, REPORTED, -...
# 103657   [DIRECT, DIRECT, -, DIRECT, JUDGEMENTAL, DIRECT]
# 103658        [-, DIRECT, DIRECT, DIRECT, DIRECT, DIRECT]
# 103660         [DIRECT, -, DIRECT, REPORTED, REPORTED, -]
#
#                                              labels_task3     split
# 100001  [[OBJECTIFICATION], [OBJECTIFICATION, SEXUAL-V...  TRAIN_ES
# 100005  [[STEREOTYPING-DOMINANCE, OBJECTIFICATION], [-...  TRAIN_ES
# 100008  [[IDEOLOGICAL-INEQUALITY], [STEREOTYPING-DOMIN...  TRAIN_ES
# 100028  [[STEREOTYPING-DOMINANCE], [-], [-], [IDEOLOGI...  TRAIN_ES
# 100036  [[STEREOTYPING-DOMINANCE, SEXUAL-VIOLENCE], [M...  TRAIN_ES
# ...                                                   ...       ...
# 103655  [[MISOGYNY-NON-SEXUAL-VIOLENCE], [MISOGYNY-NON...  TRAIN_ES
# 103656  [[STEREOTYPING-DOMINANCE, OBJECTIFICATION], [S...  TRAIN_ES
# 103657  [[MISOGYNY-NON-SEXUAL-VIOLENCE], [IDEOLOGICAL-...  TRAIN_ES
# 103658  [[-], [OBJECTIFICATION, SEXUAL-VIOLENCE], [STE...  TRAIN_ES
# 103660  [[MISOGYNY-NON-SEXUAL-VIOLENCE], [-], [OBJECTI...  TRAIN_ES
#
# [1560 rows x 11 columns]

# %%
non_sexist_en=non_sexist.loc[non_sexist.lang=="en"]
non_sexist_en
# Out:
#        id_EXIST lang                                              tweet  \
# 200008   200008   en  New to the shelves this week - looking forward...
# 200010   200010   en  I guess that’s fairly normal for a Neanderthal...
# 200023   200023   en  @JavedLSterritt He's really shit on games jour...
# 200024   200024   en  Low key, she was fr created because the Incred...
# 200025   200025   en  One of the most important (and of course, unde...
# ...         ...  ...                                                ...
# 203180   203180   en  @BFriedmanDC "The other officers yell after Jo...
# 203201   203201   en  @v1sig0th @PTSDGuts2 Get off your goddamn high...
# 203202   203202   en  I hate the phrase “when you assume it makes an...
# 203205   203205   en  To the guy who beeped at me after I'd put my h...
# 203216   203216   en  @brettk351 @Mooglet1 Nah b, this post makes YO...
#
#        number_annotators                                         annotators  \
# 200008                 6  [Annotator_420, Annotator_296, Annotator_421, ...
# 200010                 6  [Annotator_431, Annotator_432, Annotator_433, ...
# 200023                 6  [Annotator_496, Annotator_497, Annotator_498, ...
# 200024                 6  [Annotator_502, Annotator_503, Annotator_504, ...
# 200025                 6  [Annotator_508, Annotator_509, Annotator_510, ...
# ...                  ...                                                ...
# 203180                 6  [Annotator_617, Annotator_618, Annotator_619, ...
# 203201                 6  [Annotator_508, Annotator_509, Annotator_510, ...
# 203202                 6  [Annotator_703, Annotator_704, Annotator_705, ...
# 203205                 6  [Annotator_645, Annotator_646, Annotator_647, ...
# 203216                 6  [Annotator_629, Annotator_630, Annotator_631, ...
#
#          gender_annotators                          age_annotators  \
# 200008  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 200010  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 200023  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 200024  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 200025  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# ...                    ...                                     ...
# 203180  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203201  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203202  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203205  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203216  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
#
#                       labels_task1                    labels_task2  \
# 200008   [NO, NO, NO, YES, NO, NO]    [-, -, -, JUDGEMENTAL, -, -]
# 200010   [NO, NO, NO, NO, YES, NO]    [-, -, -, -, JUDGEMENTAL, -]
# 200023   [NO, NO, NO, YES, NO, NO]    [-, -, -, JUDGEMENTAL, -, -]
# 200024   [NO, NO, NO, NO, NO, YES]    [-, -, -, -, -, JUDGEMENTAL]
# 200025    [NO, NO, NO, NO, NO, NO]              [-, -, -, -, -, -]
# ...                            ...                             ...
# 203180   [NO, YES, NO, NO, NO, NO]       [-, REPORTED, -, -, -, -]
# 203201  [NO, YES, NO, NO, YES, NO]    [-, DIRECT, -, -, DIRECT, -]
# 203202  [NO, YES, NO, YES, NO, NO]    [-, DIRECT, -, DIRECT, -, -]
# 203205  [YES, NO, NO, NO, YES, NO]  [REPORTED, -, -, -, DIRECT, -]
# 203216  [NO, YES, NO, NO, NO, YES]    [-, DIRECT, -, -, -, DIRECT]
#
#                                              labels_task3     split
# 200008  [[-], [-], [-], [IDEOLOGICAL-INEQUALITY], [-],...  TRAIN_EN
# 200010  [[-], [-], [-], [-], [OBJECTIFICATION, SEXUAL-...  TRAIN_EN
# 200023  [[-], [-], [-], [IDEOLOGICAL-INEQUALITY, STERE...  TRAIN_EN
# 200024  [[-], [-], [-], [-], [-], [STEREOTYPING-DOMINA...  TRAIN_EN
# 200025                     [[-], [-], [-], [-], [-], [-]]  TRAIN_EN
# ...                                                   ...       ...
# 203180  [[-], [STEREOTYPING-DOMINANCE], [-], [-], [-],...  TRAIN_EN
# 203201  [[-], [SEXUAL-VIOLENCE], [-], [-], [STEREOTYPI...  TRAIN_EN
# 203202  [[-], [OBJECTIFICATION], [-], [STEREOTYPING-DO...  TRAIN_EN
# 203205  [[STEREOTYPING-DOMINANCE], [-], [-], [-], [STE...  TRAIN_EN
# 203216  [[-], [STEREOTYPING-DOMINANCE, MISOGYNY-NON-SE...  TRAIN_EN
#
# [1733 rows x 11 columns]

# %%
non_sexist_es=non_sexist.loc[non_sexist.lang=="es"]
non_sexist_es
# Out:
#        id_EXIST lang                                              tweet  \
# 100002   100002   es  @ultimonomada_ Si comicsgate se parece en algo...
# 100003   100003   es  @Steven2897 Lee sobre Gamergate, y como eso ha...
# 100006   100006   es  @yonkykong Aaah sí. Andrew Dobson. El que se d...
# 100009   100009   es  .¿Conoces la #DECORACION #estilo #GAMER para #...
# 100010   100010   es  CES 2022 ASUS ROG Rise of Gamers Evento de lan...
# ...         ...  ...                                                ...
# 103616   103616   es  @petrogustavo Doctor ... repito, los niños que...
# 103619   103619   es  La Argentina explotada por todos lados, pero p...
# 103620   103620   es  Hoy con testigos el Presidente López violó la ...
# 103639   103639   es  cahcake ya casi queda poco para el años zorra ...
# 103651   103651   es  @Hernandez1976 @freddyvasquez Dejen de pensar ...
#
#        number_annotators                                         annotators  \
# 100002                 6  [Annotator_7, Annotator_8, Annotator_9, Annota...
# 100003                 6  [Annotator_7, Annotator_8, Annotator_9, Annota...
# 100006                 6  [Annotator_25, Annotator_26, Annotator_27, Ann...
# 100009                 6  [Annotator_31, Annotator_32, Annotator_33, Ann...
# 100010                 6  [Annotator_37, Annotator_38, Annotator_39, Ann...
# ...                  ...                                                ...
# 103616                 6  [Annotator_139, Annotator_140, Annotator_141, ...
# 103619                 6  [Annotator_313, Annotator_314, Annotator_315, ...
# 103620                 6  [Annotator_229, Annotator_230, Annotator_231, ...
# 103639                 6  [Annotator_211, Annotator_212, Annotator_213, ...
# 103651                 6  [Annotator_253, Annotator_254, Annotator_255, ...
#
#          gender_annotators                          age_annotators  \
# 100002  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100003  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100006  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100009  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100010  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# ...                    ...                                     ...
# 103616  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 103619  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 103620  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 103639  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 103651  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
#
#                       labels_task1                       labels_task2  \
# 100002   [NO, NO, NO, NO, YES, NO]            [-, -, -, -, DIRECT, -]
# 100003    [NO, NO, NO, NO, NO, NO]                 [-, -, -, -, -, -]
# 100006    [NO, NO, NO, NO, NO, NO]                 [-, -, -, -, -, -]
# 100009    [NO, NO, NO, NO, NO, NO]                 [-, -, -, -, -, -]
# 100010   [NO, NO, YES, NO, NO, NO]            [-, -, DIRECT, -, -, -]
# ...                            ...                                ...
# 103616  [NO, NO, YES, NO, YES, NO]     [-, -, REPORTED, -, DIRECT, -]
# 103619    [NO, NO, NO, NO, NO, NO]                 [-, -, -, -, -, -]
# 103620    [NO, NO, NO, NO, NO, NO]                 [-, -, -, -, -, -]
# 103639  [NO, YES, YES, NO, NO, NO]  [-, DIRECT, JUDGEMENTAL, -, -, -]
# 103651  [NO, YES, NO, NO, YES, NO]       [-, DIRECT, -, -, DIRECT, -]
#
#                                              labels_task3     split
# 100002       [[-], [-], [-], [-], [OBJECTIFICATION], [-]]  TRAIN_ES
# 100003                     [[-], [-], [-], [-], [-], [-]]  TRAIN_ES
# 100006                     [[-], [-], [-], [-], [-], [-]]  TRAIN_ES
# 100009                     [[-], [-], [-], [-], [-], [-]]  TRAIN_ES
# 100010  [[-], [-], [STEREOTYPING-DOMINANCE], [-], [-],...  TRAIN_ES
# ...                                                   ...       ...
# 103616  [[-], [-], [SEXUAL-VIOLENCE], [-], [IDEOLOGICA...  TRAIN_ES
# 103619                     [[-], [-], [-], [-], [-], [-]]  TRAIN_ES
# 103620                     [[-], [-], [-], [-], [-], [-]]  TRAIN_ES
# 103639  [[-], [MISOGYNY-NON-SEXUAL-VIOLENCE], [OBJECTI...  TRAIN_ES
# 103651  [[-], [OBJECTIFICATION], [-], [-], [OBJECTIFIC...  TRAIN_ES
#
# [1634 rows x 11 columns]

# %%
ambiguous=df.loc[df['labels_task1'].apply(lambda x:x.count('YES'))==3]
ambiguous
# Out:
#        id_EXIST lang                                              tweet  \
# 100004   100004   es  @Lunariita7 Un retraso social bastante lamenta...
# 100007   100007   es  @glutamatom @JoaquinAdolfoC Estaba del lado de...
# 100025   100025   es  @myglookhere las mujeres no deberíamos vivir c...
# 100026   100026   es  Ya son las 00:00 en arabia, por favor difundan...
# 100030   100030   es  @Quora Is a great example of this, they don't ...
# ...         ...  ...                                                ...
# 203217   203217   en  Wafc honest take of today…….long ball side doe...
# 203219   203219   en  you ever go to press qrt but then you rt but i...
# 203220   203220   en  @SzMarsupial @mountain_ghosts Well admitting t...
# 203238   203238   en  @Bobbywade31 @DavidMcGovern In other words, if...
# 203250   203250   en  Mine and Kc way of completing each other is by...
#
#        number_annotators                                         annotators  \
# 100004                 6  [Annotator_13, Annotator_14, Annotator_15, Ann...
# 100007                 6  [Annotator_25, Annotator_26, Annotator_27, Ann...
# 100025                 6  [Annotator_97, Annotator_98, Annotator_99, Ann...
# 100026                 6  [Annotator_103, Annotator_104, Annotator_105, ...
# 100030                 6  [Annotator_109, Annotator_110, Annotator_111, ...
# ...                  ...                                                ...
# 203217                 6  [Annotator_651, Annotator_652, Annotator_653, ...
# 203219                 6  [Annotator_680, Annotator_681, Annotator_682, ...
# 203220                 6  [Annotator_617, Annotator_618, Annotator_619, ...
# 203238                 6  [Annotator_674, Annotator_675, Annotator_676, ...
# 203250                 6  [Annotator_629, Annotator_630, Annotator_631, ...
#
#          gender_annotators                          age_annotators  \
# 100004  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100007  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100025  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100026  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100030  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# ...                    ...                                     ...
# 203217  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203219  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203220  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203238  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203250  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
#
#                        labels_task1  \
# 100004  [NO, NO, YES, NO, YES, YES]
# 100007  [NO, YES, YES, NO, NO, YES]
# 100025  [YES, NO, NO, YES, YES, NO]
# 100026  [NO, NO, YES, YES, NO, YES]
# 100030  [YES, YES, NO, YES, NO, NO]
# ...                             ...
# 203217  [NO, NO, NO, YES, YES, YES]
# 203219  [NO, NO, YES, NO, YES, YES]
# 203220  [YES, YES, NO, YES, NO, NO]
# 203238  [NO, NO, NO, YES, YES, YES]
# 203250  [NO, NO, YES, NO, YES, YES]
#
#                                             labels_task2  \
# 100004             [-, -, DIRECT, -, REPORTED, REPORTED]
# 100007                [-, UNKNOWN, DIRECT, -, -, DIRECT]
# 100025  [JUDGEMENTAL, -, -, JUDGEMENTAL, JUDGEMENTAL, -]
# 100026        [-, -, REPORTED, REPORTED, -, JUDGEMENTAL]
# 100030           [REPORTED, REPORTED, -, REPORTED, -, -]
# ...                                                  ...
# 203217                 [-, -, -, DIRECT, DIRECT, DIRECT]
# 203219                 [-, -, DIRECT, -, DIRECT, DIRECT]
# 203220                 [DIRECT, DIRECT, -, DIRECT, -, -]
# 203238       [-, -, -, JUDGEMENTAL, DIRECT, JUDGEMENTAL]
# 203250            [-, -, JUDGEMENTAL, -, DIRECT, DIRECT]
#
#                                              labels_task3     split
# 100004  [[-], [-], [IDEOLOGICAL-INEQUALITY], [-], [IDE...  TRAIN_ES
# 100007  [[-], [UNKNOWN], [MISOGYNY-NON-SEXUAL-VIOLENCE...  TRAIN_ES
# 100025  [[MISOGYNY-NON-SEXUAL-VIOLENCE], [-], [-], [SE...  TRAIN_ES
# 100026  [[-], [-], [OBJECTIFICATION], [STEREOTYPING-DO...  TRAIN_ES
# 100030  [[STEREOTYPING-DOMINANCE, OBJECTIFICATION, SEX...  TRAIN_ES
# ...                                                   ...       ...
# 203217  [[-], [-], [-], [STEREOTYPING-DOMINANCE, OBJEC...  TRAIN_EN
# 203219  [[-], [-], [SEXUAL-VIOLENCE], [-], [SEXUAL-VIO...  TRAIN_EN
# 203220  [[STEREOTYPING-DOMINANCE], [SEXUAL-VIOLENCE, M...  TRAIN_EN
# 203238  [[-], [-], [-], [IDEOLOGICAL-INEQUALITY], [IDE...  TRAIN_EN
# 203250  [[-], [-], [STEREOTYPING-DOMINANCE, OBJECTIFIC...  TRAIN_EN
#
# [856 rows x 11 columns]

# %%
df.loc[df['labels_task1'].apply(lambda x:x.count('YES'))==4]
# Out:
#        id_EXIST lang                                              tweet  \
# 100005   100005   es  @novadragon21 @icep4ck @TvDannyZ Entonces como...
# 100028   100028   es  @ShahidForChange @TeamPelosi Quiet, sexist ^%$...
# 100042   100042   es  @DavidSpringMan @Tuices @JessicaFillol Pues mi...
# 100047   100047   es  Caso #LaManada: Heredia es la abogada de la ví...
# 100048   100048   es  Alejandro Saavedra, violador parte de #laManad...
# ...         ...  ...                                                ...
# 203237   203237   en  Blanche: Oh, Sophia. How nice to see you.    S...
# 203240   203240   en  @BruinJustine @CortesSteve @GregAbbott_TX You ...
# 203244   203244   en  I put on gages and my girlfriend looks me in t...
# 203255   203255   en  I forgot I have a m*d that changes the drachen...
# 203258   203258   en  "Take me already" "Not yet. You gotta be ready...
#
#        number_annotators                                         annotators  \
# 100005                 6  [Annotator_19, Annotator_20, Annotator_21, Ann...
# 100028                 6  [Annotator_109, Annotator_110, Annotator_111, ...
# 100042                 6  [Annotator_127, Annotator_128, Annotator_129, ...
# 100047                 6  [Annotator_145, Annotator_146, Annotator_147, ...
# 100048                 6  [Annotator_37, Annotator_38, Annotator_39, Ann...
# ...                  ...                                                ...
# 203237                 6  [Annotator_674, Annotator_675, Annotator_676, ...
# 203240                 6  [Annotator_680, Annotator_681, Annotator_682, ...
# 203244                 6  [Annotator_425, Annotator_426, Annotator_427, ...
# 203255                 6  [Annotator_674, Annotator_675, Annotator_676, ...
# 203258                 6  [Annotator_467, Annotator_468, Annotator_469, ...
#
#          gender_annotators                          age_annotators  \
# 100005  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100028  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100042  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100047  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100048  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# ...                    ...                                     ...
# 203237  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203240  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203244  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203255  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203258  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
#
#                         labels_task1  \
# 100005  [YES, NO, YES, NO, YES, YES]
# 100028  [YES, NO, NO, YES, YES, YES]
# 100042  [NO, YES, YES, NO, YES, YES]
# 100047  [YES, YES, NO, NO, YES, YES]
# 100048  [NO, YES, YES, YES, NO, YES]
# ...                              ...
# 203237  [YES, NO, YES, NO, YES, YES]
# 203240  [YES, YES, YES, NO, YES, NO]
# 203244  [YES, YES, NO, NO, YES, YES]
# 203255  [NO, NO, YES, YES, YES, YES]
# 203258  [NO, YES, NO, YES, YES, YES]
#
#                                              labels_task2  \
# 100005  [REPORTED, -, JUDGEMENTAL, -, JUDGEMENTAL, DIR...
# 100028        [JUDGEMENTAL, -, -, DIRECT, DIRECT, DIRECT]
# 100042  [-, REPORTED, JUDGEMENTAL, -, REPORTED, JUDGEM...
# 100047    [DIRECT, REPORTED, -, -, JUDGEMENTAL, REPORTED]
# 100048     [-, REPORTED, REPORTED, REPORTED, -, REPORTED]
# ...                                                   ...
# 203237       [REPORTED, -, DIRECT, -, REPORTED, REPORTED]
# 203240             [DIRECT, DIRECT, DIRECT, -, DIRECT, -]
# 203244      [JUDGEMENTAL, REPORTED, -, -, DIRECT, DIRECT]
# 203255   [-, -, DIRECT, JUDGEMENTAL, JUDGEMENTAL, DIRECT]
# 203258        [-, DIRECT, -, DIRECT, DIRECT, JUDGEMENTAL]
#
#                                              labels_task3     split
# 100005  [[STEREOTYPING-DOMINANCE, OBJECTIFICATION], [-...  TRAIN_ES
# 100028  [[STEREOTYPING-DOMINANCE], [-], [-], [IDEOLOGI...  TRAIN_ES
# 100042  [[-], [IDEOLOGICAL-INEQUALITY, SEXUAL-VIOLENCE...  TRAIN_ES
# 100047  [[SEXUAL-VIOLENCE], [SEXUAL-VIOLENCE], [-], [-...  TRAIN_ES
# 100048  [[-], [SEXUAL-VIOLENCE], [MISOGYNY-NON-SEXUAL-...  TRAIN_ES
# ...                                                   ...       ...
# 203237  [[OBJECTIFICATION], [-], [OBJECTIFICATION], [-...  TRAIN_EN
# 203240  [[OBJECTIFICATION, SEXUAL-VIOLENCE], [OBJECTIF...  TRAIN_EN
# 203244  [[IDEOLOGICAL-INEQUALITY], [OBJECTIFICATION], ...  TRAIN_EN
# 203255  [[-], [-], [OBJECTIFICATION], [IDEOLOGICAL-INE...  TRAIN_EN
# 203258  [[-], [OBJECTIFICATION], [-], [SEXUAL-VIOLENCE...  TRAIN_EN
#
# [910 rows x 11 columns]

# %%
df.loc[df['labels_task1'].apply(lambda x:x.count('YES'))==5]
# Out:
#        id_EXIST lang                                              tweet  \
# 100001   100001   es  @TheChiflis Ignora al otro, es un capullo.El p...
# 100036   100036   es          @Harassed_girl loca d mierda en k momento
# 100038   100038   es  @spacland encima siempre a la misma pobre tisi...
# 100044   100044   es  @jmrane #Lamanada (agresión sexual en Navarra)...
# 100060   100060   es  Lo de Lopetegui en rueda de prensa diciendo no...
# ...         ...  ...                                                ...
# 203248   203248   en  me to the cat: don't stick your ass up like th...
# 203249   203249   en         “wow you look like a whore”“thank you!”😂😂😂
# 203252   203252   en  “You look like a whore” if you think I’m cute ...
# 203254   203254   en  @ShefVaidya Ma'am if I say that you look like ...
# 203260   203260   en  ik when mandy says “you look like a whore” i l...
#
#        number_annotators                                         annotators  \
# 100001                 6  [Annotator_1, Annotator_2, Annotator_3, Annota...
# 100036                 6  [Annotator_115, Annotator_116, Annotator_117, ...
# 100038                 6  [Annotator_115, Annotator_116, Annotator_117, ...
# 100044                 6  [Annotator_91, Annotator_92, Annotator_93, Ann...
# 100060                 6  [Annotator_55, Annotator_56, Annotator_57, Ann...
# ...                  ...                                                ...
# 203248                 6  [Annotator_265, Annotator_709, Annotator_710, ...
# 203249                 6  [Annotator_467, Annotator_468, Annotator_469, ...
# 203252                 6  [Annotator_617, Annotator_618, Annotator_619, ...
# 203254                 6  [Annotator_668, Annotator_669, Annotator_670, ...
# 203260                 6  [Annotator_473, Annotator_474, Annotator_475, ...
#
#          gender_annotators                          age_annotators  \
# 100001  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100036  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100038  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100044  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100060  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# ...                    ...                                     ...
# 203248  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203249  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203252  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203254  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203260  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
#
#                          labels_task1  \
# 100001  [YES, YES, NO, YES, YES, YES]
# 100036  [YES, YES, YES, YES, YES, NO]
# 100038  [YES, YES, YES, YES, YES, NO]
# 100044  [NO, YES, YES, YES, YES, YES]
# 100060  [YES, YES, YES, YES, NO, YES]
# ...                               ...
# 203248  [YES, YES, YES, NO, YES, YES]
# 203249  [YES, YES, NO, YES, YES, YES]
# 203252  [YES, YES, NO, YES, YES, YES]
# 203254  [YES, YES, NO, YES, YES, YES]
# 203260  [YES, YES, YES, NO, YES, YES]
#
#                                              labels_task2  \
# 100001  [REPORTED, JUDGEMENTAL, -, REPORTED, JUDGEMENT...
# 100036        [DIRECT, DIRECT, DIRECT, DIRECT, DIRECT, -]
# 100038  [REPORTED, JUDGEMENTAL, DIRECT, REPORTED, DIRE...
# 100044  [-, REPORTED, REPORTED, REPORTED, JUDGEMENTAL,...
# 100060  [JUDGEMENTAL, DIRECT, JUDGEMENTAL, DIRECT, -, ...
# ...                                                   ...
# 203248        [DIRECT, DIRECT, DIRECT, -, DIRECT, DIRECT]
# 203249  [DIRECT, REPORTED, -, DIRECT, DIRECT, JUDGEMEN...
# 203252  [DIRECT, DIRECT, -, DIRECT, JUDGEMENTAL, JUDGE...
# 203254  [DIRECT, DIRECT, -, REPORTED, DIRECT, JUDGEMEN...
# 203260  [DIRECT, DIRECT, REPORTED, -, JUDGEMENTAL, REP...
#
#                                              labels_task3     split
# 100001  [[OBJECTIFICATION], [OBJECTIFICATION, SEXUAL-V...  TRAIN_ES
# 100036  [[STEREOTYPING-DOMINANCE, SEXUAL-VIOLENCE], [M...  TRAIN_ES
# 100038  [[STEREOTYPING-DOMINANCE, OBJECTIFICATION], [S...  TRAIN_ES
# 100044  [[-], [SEXUAL-VIOLENCE], [SEXUAL-VIOLENCE], [S...  TRAIN_ES
# 100060  [[OBJECTIFICATION], [SEXUAL-VIOLENCE], [STEREO...  TRAIN_ES
# ...                                                   ...       ...
# 203248  [[OBJECTIFICATION, SEXUAL-VIOLENCE], [MISOGYNY...  TRAIN_EN
# 203249  [[OBJECTIFICATION, SEXUAL-VIOLENCE], [OBJECTIF...  TRAIN_EN
# 203252  [[SEXUAL-VIOLENCE], [MISOGYNY-NON-SEXUAL-VIOLE...  TRAIN_EN
# 203254  [[OBJECTIFICATION, MISOGYNY-NON-SEXUAL-VIOLENC...  TRAIN_EN
# 203260  [[STEREOTYPING-DOMINANCE], [OBJECTIFICATION], ...  TRAIN_EN
#
# [972 rows x 11 columns]

# %%
df.loc[df['labels_task1'].apply(lambda x:x.count('YES'))==6]
# Out:
#        id_EXIST lang                                              tweet  \
# 100008   100008   es  @BestKabest Esta gringa sigue llorando por el ...
# 100071   100071   es  #PorSiNoLoViste #Espectaculos #Acoso #MeToo 🟣L...
# 100076   100076   es  EL #METOO Y EL MUNDO LITERARIO | Acosadores: l...
# 100089   100089   es  @Pretorian_MGTOW No se que le pasó a ésta muje...
# 100110   100110   es  Y recuerden que decir "No todos los hombres" n...
# ...         ...  ...                                                ...
# 203251   203251   en  "you look like a whore" I'm literally wearing ...
# 203253   203253   en  Who fucking lied to you? You look like a whore...
# 203256   203256   en  idk why y’all bitches think having half your a...
# 203257   203257   en  This has been a part of an experiment with @Wo...
# 203259   203259   en  @clintneedcoffee why do you look like a whore?...
#
#        number_annotators                                         annotators  \
# 100008                 6  [Annotator_25, Annotator_26, Annotator_27, Ann...
# 100071                 6  [Annotator_205, Annotator_206, Annotator_207, ...
# 100076                 6  [Annotator_109, Annotator_110, Annotator_111, ...
# 100089                 6  [Annotator_1, Annotator_2, Annotator_3, Annota...
# 100110                 6  [Annotator_151, Annotator_152, Annotator_153, ...
# ...                  ...                                                ...
# 203251                 6  [Annotator_473, Annotator_474, Annotator_475, ...
# 203253                 6  [Annotator_617, Annotator_618, Annotator_619, ...
# 203256                 6  [Annotator_478, Annotator_479, Annotator_480, ...
# 203257                 6  [Annotator_668, Annotator_669, Annotator_670, ...
# 203259                 6  [Annotator_674, Annotator_675, Annotator_676, ...
#
#          gender_annotators                          age_annotators  \
# 100008  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100071  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100076  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100089  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# 100110  [F, F, F, M, M, M]  [18-22, 23-45, 46+, 46+, 23-45, 18-22]
# ...                    ...                                     ...
# 203251  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203253  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203256  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203257  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
# 203259  [F, F, M, M, M, F]  [18-22, 23-45, 18-22, 23-45, 46+, 46+]
#
#                           labels_task1  \
# 100008  [YES, YES, YES, YES, YES, YES]
# 100071  [YES, YES, YES, YES, YES, YES]
# 100076  [YES, YES, YES, YES, YES, YES]
# 100089  [YES, YES, YES, YES, YES, YES]
# 100110  [YES, YES, YES, YES, YES, YES]
# ...                                ...
# 203251  [YES, YES, YES, YES, YES, YES]
# 203253  [YES, YES, YES, YES, YES, YES]
# 203256  [YES, YES, YES, YES, YES, YES]
# 203257  [YES, YES, YES, YES, YES, YES]
# 203259  [YES, YES, YES, YES, YES, YES]
#
#                                              labels_task2  \
# 100008  [DIRECT, DIRECT, DIRECT, JUDGEMENTAL, DIRECT, ...
# 100071  [REPORTED, REPORTED, REPORTED, REPORTED, REPOR...
# 100076  [REPORTED, DIRECT, REPORTED, REPORTED, REPORTE...
# 100089  [DIRECT, JUDGEMENTAL, DIRECT, DIRECT, DIRECT, ...
# 100110  [JUDGEMENTAL, JUDGEMENTAL, DIRECT, REPORTED, R...
# ...                                                   ...
# 203251  [REPORTED, REPORTED, REPORTED, DIRECT, REPORTE...
# 203253   [DIRECT, DIRECT, DIRECT, DIRECT, DIRECT, DIRECT]
# 203256  [JUDGEMENTAL, DIRECT, DIRECT, DIRECT, JUDGEMEN...
# 203257  [JUDGEMENTAL, REPORTED, JUDGEMENTAL, DIRECT, J...
# 203259  [DIRECT, DIRECT, DIRECT, DIRECT, JUDGEMENTAL, ...
#
#                                              labels_task3     split
# 100008  [[IDEOLOGICAL-INEQUALITY], [STEREOTYPING-DOMIN...  TRAIN_ES
# 100071  [[STEREOTYPING-DOMINANCE, SEXUAL-VIOLENCE], [S...  TRAIN_ES
# 100076  [[IDEOLOGICAL-INEQUALITY, STEREOTYPING-DOMINAN...  TRAIN_ES
# 100089  [[OBJECTIFICATION, SEXUAL-VIOLENCE], [STEREOTY...  TRAIN_ES
# 100110  [[IDEOLOGICAL-INEQUALITY, STEREOTYPING-DOMINAN...  TRAIN_ES
# ...                                                   ...       ...
# 203251  [[STEREOTYPING-DOMINANCE, OBJECTIFICATION], [O...  TRAIN_EN
# 203253  [[OBJECTIFICATION], [OBJECTIFICATION, SEXUAL-V...  TRAIN_EN
# 203256  [[OBJECTIFICATION], [STEREOTYPING-DOMINANCE, S...  TRAIN_EN
# 203257  [[OBJECTIFICATION], [OBJECTIFICATION], [OBJECT...  TRAIN_EN
# 203259  [[OBJECTIFICATION, SEXUAL-VIOLENCE, MISOGYNY-N...  TRAIN_EN
#
# [815 rows x 11 columns]

# %%
annotators=df.annotators.to_numpy().flatten().tolist()
Dict_all={}
for ans in annotators: 
    for individual in ans: 
        if Dict_all.get(individual) is not None:
            Dict_all[individual]=Dict_all[individual]+1
        else:
            Dict_all[individual]=1

# %%
ambi_annotators=ambiguous.annotators.to_numpy().flatten().tolist()
Dict_ambi={}
for ans in ambi_annotators: 
    for individuals in ans: 
        if Dict_ambi.get(individuals) is not None:
            Dict_ambi[individuals]=Dict_ambi[individuals]+1
        else:
            Dict_ambi[individuals]=1

# %%
annotators_en = english.annotators.to_numpy().flatten().tolist()
annotators_es = spanish.annotators.to_numpy().flatten().tolist()

# %%
Dict_CW = {}
sexist_en = sexist_en.set_index(sexist_en['id_EXIST'])
non_sexist_en = non_sexist_en.set_index(non_sexist_en['id_EXIST'])
for (i, ans) in enumerate(annotators_en):
	index = str(200000 + i + 1)
	if index in sexist_en.index:
		for (j, individual) in enumerate(ans):
			if Dict_CW.get(individual) is not None:
				if sexist_en.loc[sexist_en.id_EXIST==index]['labels_task1'].tolist()[0][j] == 'YES':
					Dict_CW[individual][0] = Dict_CW[individual][0] + 1
				else:
					Dict_CW[individual][1] = Dict_CW[individual][1] + 1
			else:
				if sexist_en.loc[sexist_en.id_EXIST==index]['labels_task1'].tolist()[0][j] == 'YES':
					Dict_CW[individual] = [1, 0]
				else:
					Dict_CW[individual] = [0, 1]
	elif index in non_sexist_en.index:
		for (j, individual) in enumerate(ans):
			if Dict_CW.get(individual) is not None:
				if non_sexist_en.loc[non_sexist_en.id_EXIST==index]['labels_task1'].tolist()[0][j] == 'NO':
					Dict_CW[individual][0] = Dict_CW[individual][0] + 1
				else:
					Dict_CW[individual][1] = Dict_CW[individual][1] + 1
			else:
				if non_sexist_en.loc[non_sexist_en.id_EXIST==index]['labels_task1'].tolist()[0][j] == 'NO':
					Dict_CW[individual] = [1, 0]
				else:
					Dict_CW[individual] = [0, 1]

# %%
sexist_es = sexist_es.set_index(sexist_es['id_EXIST'])
non_sexist_es = non_sexist_es.set_index(non_sexist_es['id_EXIST'])
for (i, ans) in enumerate(annotators_es):
	index = str(100000 + i + 1)
	if index in sexist_es.index:
		for (j, individual) in enumerate(ans):
			if Dict_CW.get(individual) is not None:
				if sexist_es.loc[sexist_es.id_EXIST==index]['labels_task1'].tolist()[0][j] == 'YES':
					Dict_CW[individual][0] = Dict_CW[individual][0] + 1
				else:
					Dict_CW[individual][1] = Dict_CW[individual][1] + 1
			else:
				if sexist_es.loc[sexist_es.id_EXIST==index]['labels_task1'].tolist()[0][j] == 'YES':
					Dict_CW[individual] = [1, 0]
				else:
					Dict_CW[individual] = [0, 1]
	elif index in non_sexist_es.index:
		for (j, individual) in enumerate(ans):
			if Dict_CW.get(individual) is not None:
				if non_sexist_es.loc[non_sexist_es.id_EXIST==index]['labels_task1'].tolist()[0][j] == 'NO':
					Dict_CW[individual][0] = Dict_CW[individual][0] + 1
				else:
					Dict_CW[individual][1] = Dict_CW[individual][1] + 1
			else:
				if non_sexist_es.loc[non_sexist_es.id_EXIST==index]['labels_task1'].tolist()[0][j] == 'NO':
					Dict_CW[individual] = [1, 0]
				else:
					Dict_CW[individual] = [0, 1]

# %%
ann_keys = list(Dict_CW.keys())
ann_keys_int = [int(s.split('_')[1]) for s in ann_keys]
ann_keys_new = [x for _,x in sorted(zip(ann_keys_int, ann_keys))]
Dict_CW_new = {i: Dict_CW[i] for i in ann_keys_new}
Dict_CW_new
# Out:
# {'Annotator_1': [39, 13],
#  'Annotator_2': [48, 4],
#  'Annotator_3': [42, 10],
#  'Annotator_4': [49, 3],
#  'Annotator_5': [46, 6],
#  'Annotator_6': [45, 7],
#  'Annotator_7': [45, 8],
#  'Annotator_8': [48, 5],
#  'Annotator_9': [48, 5],
#  'Annotator_10': [44, 9],
#  'Annotator_11': [45, 8],
#  'Annotator_12': [39, 14],
#  'Annotator_13': [43, 6],
#  'Annotator_14': [44, 5],
#  'Annotator_15': [34, 15],
#  'Annotator_16': [38, 11],
#  'Annotator_17': [44, 5],
#  'Annotator_18': [40, 9],
#  'Annotator_19': [49, 2],
#  'Annotator_20': [45, 6],
#  'Annotator_21': [44, 7],
#  'Annotator_22': [38, 13],
#  'Annotator_23': [36, 15],
#  'Annotator_24': [44, 7],
#  'Annotator_25': [30, 11],
#  'Annotator_26': [37, 4],
#  'Annotator_27': [80, 11],
#  'Annotator_28': [32, 9],
#  'Annotator_29': [35, 6],
#  'Annotator_30': [30, 11],
#  'Annotator_31': [29, 16],
#  'Annotator_32': [42, 3],
#  'Annotator_33': [39, 6],
#  'Annotator_34': [40, 5],
#  'Annotator_35': [39, 6],
#  'Annotator_36': [41, 4],
#  'Annotator_37': [45, 6],
#  'Annotator_38': [43, 8],
#  'Annotator_39': [44, 7],
#  'Annotator_40': [47, 4],
#  'Annotator_41': [46, 5],
#  'Annotator_42': [45, 6],
#  'Annotator_43': [86, 14],
#  'Annotator_44': [48, 4],
#  'Annotator_45': [48, 4],
#  'Annotator_46': [31, 21],
#  'Annotator_47': [43, 9],
#  'Annotator_48': [37, 15],
#  'Annotator_49': [41, 7],
#  'Annotator_50': [46, 2],
#  'Annotator_51': [40, 8],
#  'Annotator_52': [37, 11],
#  'Annotator_53': [38, 10],
#  'Annotator_54': [39, 9],
#  'Annotator_55': [47, 3],
#  'Annotator_56': [44, 6],
#  'Annotator_57': [43, 7],
#  'Annotator_58': [40, 10],
#  'Annotator_59': [35, 15],
#  'Annotator_60': [42, 8],
#  'Annotator_61': [47, 8],
#  'Annotator_62': [48, 7],
#  'Annotator_63': [49, 6],
#  'Annotator_64': [48, 7],
#  'Annotator_65': [48, 7],
#  'Annotator_66': [49, 6],
#  'Annotator_67': [42, 7],
#  'Annotator_68': [45, 4],
#  'Annotator_69': [41, 8],
#  'Annotator_70': [36, 13],
#  'Annotator_71': [30, 19],
#  'Annotator_72': [42, 7],
#  'Annotator_73': [45, 3],
#  'Annotator_74': [37, 11],
#  'Annotator_75': [44, 4],
#  'Annotator_76': [36, 12],
#  'Annotator_77': [40, 8],
#  'Annotator_78': [40, 8],
#  'Annotator_79': [48, 2],
#  'Annotator_80': [46, 4],
#  'Annotator_81': [46, 4],
#  'Annotator_82': [41, 9],
#  'Annotator_83': [41, 9],
#  'Annotator_84': [38, 12],
#  'Annotator_85': [44, 5],
#  'Annotator_86': [46, 3],
#  'Annotator_87': [40, 9],
#  'Annotator_88': [32, 17],
#  'Annotator_89': [28, 21],
#  'Annotator_90': [36, 13],
#  'Annotator_91': [42, 10],
#  'Annotator_92': [47, 5],
#  'Annotator_93': [45, 7],
#  'Annotator_94': [49, 3],
#  'Annotator_95': [45, 7],
#  'Annotator_96': [43, 9],
#  'Annotator_97': [43, 4],
#  'Annotator_98': [41, 6],
#  'Annotator_99': [21, 26],
#  'Annotator_100': [41, 6],
#  'Annotator_101': [42, 5],
#  'Annotator_102': [35, 12],
#  'Annotator_103': [42, 5],
#  'Annotator_104': [39, 8],
#  'Annotator_105': [36, 11],
#  'Annotator_106': [44, 3],
#  'Annotator_107': [42, 5],
#  'Annotator_108': [47, 0],
#  'Annotator_109': [48, 5],
#  'Annotator_110': [45, 8],
#  'Annotator_111': [40, 13],
#  'Annotator_112': [47, 6],
#  'Annotator_113': [49, 4],
#  'Annotator_114': [45, 8],
#  'Annotator_115': [40, 8],
#  'Annotator_116': [46, 2],
#  'Annotator_117': [74, 25],
#  'Annotator_118': [36, 12],
#  'Annotator_119': [42, 6],
#  'Annotator_120': [30, 18],
#  'Annotator_121': [34, 12],
#  'Annotator_122': [41, 5],
#  'Annotator_123': [28, 18],
#  'Annotator_124': [42, 4],
#  'Annotator_125': [42, 4],
#  'Annotator_126': [43, 3],
#  'Annotator_127': [49, 6],
#  'Annotator_128': [50, 5],
#  'Annotator_129': [47, 8],
#  'Annotator_130': [73, 33],
#  'Annotator_131': [55, 0],
#  'Annotator_132': [50, 5],
#  'Annotator_133': [43, 4],
#  'Annotator_134': [43, 4],
#  'Annotator_135': [38, 9],
#  'Annotator_136': [38, 9],
#  'Annotator_137': [44, 3],
#  'Annotator_138': [41, 6],
#  'Annotator_139': [44, 6],
#  'Annotator_140': [36, 14],
#  'Annotator_141': [44, 6],
#  'Annotator_142': [40, 10],
#  'Annotator_143': [30, 20],
#  'Annotator_144': [45, 5],
#  'Annotator_145': [35, 13],
#  'Annotator_146': [37, 11],
#  'Annotator_147': [40, 8],
#  'Annotator_148': [42, 6],
#  'Annotator_149': [43, 5],
#  'Annotator_150': [36, 12],
#  'Annotator_151': [49, 4],
#  'Annotator_152': [44, 9],
#  'Annotator_153': [44, 9],
#  'Annotator_154': [50, 3],
#  'Annotator_155': [45, 8],
#  'Annotator_156': [46, 7],
#  'Annotator_157': [45, 2],
#  'Annotator_158': [43, 4],
#  'Annotator_159': [41, 6],
#  'Annotator_160': [39, 8],
#  'Annotator_161': [38, 9],
#  'Annotator_162': [42, 5],
#  'Annotator_163': [46, 4],
#  'Annotator_164': [44, 6],
#  'Annotator_165': [41, 9],
#  'Annotator_166': [40, 10],
#  'Annotator_167': [43, 7],
#  'Annotator_168': [41, 9],
#  'Annotator_169': [44, 4],
#  'Annotator_170': [41, 7],
#  'Annotator_171': [36, 12],
#  'Annotator_172': [77, 19],
#  'Annotator_173': [44, 4],
#  'Annotator_174': [43, 5],
#  'Annotator_175': [42, 5],
#  'Annotator_176': [44, 3],
#  'Annotator_177': [43, 4],
#  'Annotator_178': [37, 10],
#  'Annotator_179': [39, 8],
#  'Annotator_180': [38, 9],
#  'Annotator_181': [44, 4],
#  'Annotator_182': [46, 2],
#  'Annotator_183': [45, 3],
#  'Annotator_184': [41, 7],
#  'Annotator_185': [43, 5],
#  'Annotator_186': [38, 10],
#  'Annotator_187': [84, 19],
#  'Annotator_188': [42, 10],
#  'Annotator_189': [40, 12],
#  'Annotator_190': [86, 16],
#  'Annotator_191': [46, 6],
#  'Annotator_192': [41, 11],
#  'Annotator_193': [37, 11],
#  'Annotator_194': [42, 6],
#  'Annotator_195': [35, 13],
#  'Annotator_196': [47, 1],
#  'Annotator_197': [42, 6],
#  'Annotator_198': [40, 8],
#  'Annotator_199': [37, 12],
#  'Annotator_200': [43, 6],
#  'Annotator_201': [43, 6],
#  'Annotator_202': [39, 10],
#  'Annotator_203': [42, 7],
#  'Annotator_204': [39, 10],
#  'Annotator_205': [34, 11],
#  'Annotator_206': [40, 5],
#  'Annotator_207': [40, 5],
#  'Annotator_208': [42, 3],
#  'Annotator_209': [40, 5],
#  'Annotator_210': [37, 8],
#  'Annotator_211': [39, 11],
#  'Annotator_212': [46, 4],
#  'Annotator_213': [41, 9],
#  'Annotator_214': [43, 7],
#  'Annotator_215': [43, 7],
#  'Annotator_216': [39, 11],
#  'Annotator_217': [43, 5],
#  'Annotator_218': [38, 10],
#  'Annotator_219': [44, 4],
#  'Annotator_220': [43, 5],
#  'Annotator_221': [42, 6],
#  'Annotator_222': [44, 4],
#  'Annotator_223': [45, 4],
#  'Annotator_224': [40, 9],
#  'Annotator_225': [41, 8],
#  'Annotator_226': [35, 14],
#  'Annotator_227': [42, 7],
#  'Annotator_228': [47, 2],
#  'Annotator_229': [42, 6],
#  'Annotator_230': [46, 2],
#  'Annotator_231': [40, 8],
#  'Annotator_232': [23, 25],
#  'Annotator_233': [39, 9],
#  'Annotator_234': [43, 5],
#  'Annotator_235': [46, 6],
#  'Annotator_236': [46, 6],
#  'Annotator_237': [47, 5],
#  'Annotator_238': [42, 10],
#  'Annotator_239': [47, 5],
#  'Annotator_240': [44, 8],
#  'Annotator_241': [45, 6],
#  'Annotator_242': [46, 5],
#  'Annotator_243': [42, 9],
#  'Annotator_244': [49, 2],
#  'Annotator_245': [46, 5],
#  'Annotator_246': [44, 7],
#  'Annotator_247': [39, 11],
#  'Annotator_248': [46, 4],
#  'Annotator_249': [43, 7],
#  'Annotator_250': [34, 16],
#  'Annotator_251': [42, 8],
#  'Annotator_252': [34, 16],
#  'Annotator_253': [45, 6],
#  'Annotator_254': [36, 15],
#  'Annotator_255': [43, 8],
#  'Annotator_256': [37, 14],
#  'Annotator_257': [43, 8],
#  'Annotator_258': [44, 7],
#  'Annotator_259': [40, 9],
#  'Annotator_260': [42, 7],
#  'Annotator_261': [43, 6],
#  'Annotator_262': [33, 16],
#  'Annotator_263': [37, 12],
#  'Annotator_264': [43, 6],
#  'Annotator_265': [92, 15],
#  'Annotator_266': [47, 6],
#  'Annotator_267': [47, 6],
#  'Annotator_268': [39, 14],
#  'Annotator_269': [44, 9],
#  'Annotator_270': [36, 17],
#  'Annotator_271': [42, 8],
#  'Annotator_272': [42, 8],
#  'Annotator_273': [38, 12],
#  'Annotator_274': [42, 8],
#  'Annotator_275': [41, 9],
#  'Annotator_276': [44, 6],
#  'Annotator_277': [43, 4],
#  'Annotator_278': [41, 6],
#  'Annotator_279': [33, 14],
#  'Annotator_280': [45, 2],
#  'Annotator_281': [43, 4],
#  'Annotator_282': [40, 7],
#  'Annotator_283': [10, 1],
#  'Annotator_284': [10, 1],
#  'Annotator_285': [11, 0],
#  'Annotator_286': [8, 3],
#  'Annotator_287': [8, 3],
#  'Annotator_288': [11, 0],
#  'Annotator_289': [45, 8],
#  'Annotator_290': [48, 5],
#  'Annotator_291': [43, 10],
#  'Annotator_292': [51, 2],
#  'Annotator_293': [48, 5],
#  'Annotator_294': [49, 4],
#  'Annotator_295': [41, 12],
#  'Annotator_296': [84, 21],
#  'Annotator_297': [47, 6],
#  'Annotator_298': [42, 11],
#  'Annotator_299': [42, 11],
#  'Annotator_300': [49, 4],
#  'Annotator_301': [44, 6],
#  'Annotator_302': [43, 7],
#  'Annotator_303': [42, 8],
#  'Annotator_304': [43, 7],
#  'Annotator_305': [39, 11],
#  'Annotator_306': [42, 8],
#  'Annotator_307': [43, 5],
#  'Annotator_308': [43, 5],
#  'Annotator_309': [45, 3],
#  'Annotator_310': [40, 8],
#  'Annotator_311': [40, 8],
#  'Annotator_312': [38, 10],
#  'Annotator_313': [42, 6],
#  'Annotator_314': [43, 5],
#  'Annotator_315': [43, 5],
#  'Annotator_316': [44, 4],
#  'Annotator_317': [36, 12],
#  'Annotator_318': [43, 5],
#  'Annotator_319': [43, 6],
#  'Annotator_320': [43, 6],
#  'Annotator_321': [40, 9],
#  'Annotator_322': [43, 6],
#  'Annotator_323': [40, 9],
#  'Annotator_324': [48, 1],
#  'Annotator_325': [34, 18],
#  'Annotator_326': [51, 1],
#  'Annotator_327': [41, 11],
#  'Annotator_328': [42, 10],
#  'Annotator_329': [44, 8],
#  'Annotator_330': [48, 4],
#  'Annotator_331': [50, 15],
#  'Annotator_332': [46, 8],
#  'Annotator_333': [94, 8],
#  'Annotator_334': [45, 9],
#  'Annotator_335': [44, 10],
#  'Annotator_336': [48, 6],
#  'Annotator_337': [31, 14],
#  'Annotator_338': [40, 5],
#  'Annotator_339': [40, 5],
#  'Annotator_340': [83, 11],
#  'Annotator_341': [39, 6],
#  'Annotator_342': [41, 4],
#  'Annotator_343': [44, 6],
#  'Annotator_344': [43, 7],
#  'Annotator_345': [45, 5],
#  'Annotator_346': [36, 14],
#  'Annotator_347': [42, 8],
#  'Annotator_348': [41, 9],
#  'Annotator_349': [44, 5],
#  'Annotator_350': [42, 7],
#  'Annotator_351': [44, 5],
#  'Annotator_352': [47, 2],
#  'Annotator_353': [19, 30],
#  'Annotator_354': [41, 8],
#  'Annotator_355': [43, 6],
#  'Annotator_356': [43, 6],
#  'Annotator_357': [36, 13],
#  'Annotator_358': [42, 7],
#  'Annotator_359': [37, 12],
#  'Annotator_360': [47, 2],
#  'Annotator_361': [35, 16],
#  'Annotator_362': [47, 4],
#  'Annotator_363': [44, 7],
#  'Annotator_364': [45, 6],
#  'Annotator_365': [45, 6],
#  'Annotator_366': [44, 7],
#  'Annotator_367': [45, 7],
#  'Annotator_368': [42, 10],
#  'Annotator_369': [43, 9],
#  'Annotator_370': [46, 6],
#  'Annotator_371': [48, 4],
#  'Annotator_372': [48, 4],
#  'Annotator_373': [49, 6],
#  'Annotator_374': [51, 4],
#  'Annotator_375': [43, 12],
#  'Annotator_376': [48, 7],
#  'Annotator_377': [50, 5],
#  'Annotator_378': [52, 3],
#  'Annotator_379': [46, 5],
#  'Annotator_380': [34, 17],
#  'Annotator_381': [43, 8],
#  'Annotator_382': [34, 17],
#  'Annotator_383': [47, 4],
#  'Annotator_384': [41, 10],
#  'Annotator_385': [93, 11],
#  'Annotator_386': [50, 3],
#  'Annotator_387': [47, 6],
#  'Annotator_388': [46, 7],
#  'Annotator_389': [43, 10],
#  'Annotator_390': [46, 7],
#  'Annotator_391': [45, 4],
#  'Annotator_392': [43, 6],
#  'Annotator_393': [45, 4],
#  'Annotator_394': [40, 9],
#  'Annotator_395': [41, 8],
#  'Annotator_396': [44, 5],
#  'Annotator_397': [42, 8],
#  'Annotator_398': [46, 4],
#  'Annotator_399': [40, 10],
#  'Annotator_400': [48, 2],
#  'Annotator_401': [37, 13],
#  'Annotator_402': [40, 10],
#  'Annotator_403': [43, 6],
#  'Annotator_404': [41, 8],
#  'Annotator_405': [43, 6],
#  'Annotator_406': [42, 7],
#  'Annotator_407': [42, 7],
#  'Annotator_408': [41, 8],
#  'Annotator_409': [45, 3],
#  'Annotator_410': [40, 8],
#  'Annotator_411': [42, 6],
#  'Annotator_412': [40, 8],
#  'Annotator_413': [43, 5],
#  'Annotator_414': [28, 20],
#  'Annotator_415': [42, 7],
#  'Annotator_416': [45, 4],
#  'Annotator_417': [39, 10],
#  'Annotator_418': [43, 6],
#  'Annotator_419': [42, 7],
#  'Annotator_420': [48, 4],
#  'Annotator_421': [40, 12],
#  'Annotator_422': [47, 5],
#  'Annotator_423': [46, 6],
#  'Annotator_424': [46, 6],
#  'Annotator_425': [40, 9],
#  'Annotator_426': [45, 4],
#  'Annotator_427': [43, 6],
#  'Annotator_428': [41, 8],
#  'Annotator_429': [43, 6],
#  'Annotator_430': [42, 7],
#  'Annotator_431': [39, 8],
#  'Annotator_432': [42, 5],
#  'Annotator_433': [40, 7],
#  'Annotator_434': [42, 5],
#  'Annotator_435': [38, 9],
#  'Annotator_436': [42, 5],
#  'Annotator_437': [44, 5],
#  'Annotator_438': [38, 11],
#  'Annotator_439': [46, 3],
#  'Annotator_440': [38, 11],
#  'Annotator_441': [43, 6],
#  'Annotator_442': [49, 0],
#  'Annotator_443': [39, 7],
#  'Annotator_444': [38, 8],
#  'Annotator_445': [25, 21],
#  'Annotator_446': [41, 5],
#  'Annotator_447': [42, 4],
#  'Annotator_448': [41, 5],
#  'Annotator_449': [46, 4],
#  'Annotator_450': [40, 10],
#  'Annotator_451': [37, 13],
#  'Annotator_452': [42, 8],
#  'Annotator_453': [46, 4],
#  'Annotator_454': [35, 15],
#  'Annotator_455': [34, 17],
#  'Annotator_456': [40, 11],
#  'Annotator_457': [41, 10],
#  'Annotator_458': [47, 4],
#  'Annotator_459': [43, 8],
#  'Annotator_460': [42, 9],
#  'Annotator_461': [45, 7],
#  'Annotator_462': [41, 11],
#  'Annotator_463': [44, 8],
#  'Annotator_464': [45, 7],
#  'Annotator_465': [43, 9],
#  'Annotator_466': [46, 6],
#  'Annotator_467': [42, 7],
#  'Annotator_468': [43, 6],
#  'Annotator_469': [41, 8],
#  'Annotator_470': [42, 7],
#  'Annotator_471': [42, 7],
#  'Annotator_472': [45, 4],
#  'Annotator_473': [44, 6],
#  'Annotator_474': [41, 9],
#  'Annotator_475': [45, 5],
#  'Annotator_476': [36, 14],
#  'Annotator_477': [45, 5],
#  'Annotator_478': [38, 7],
#  'Annotator_479': [39, 6],
#  'Annotator_480': [34, 11],
#  'Annotator_481': [35, 10],
#  'Annotator_482': [40, 5],
#  'Annotator_483': [41, 4],
#  'Annotator_484': [43, 6],
#  'Annotator_485': [45, 4],
#  'Annotator_486': [42, 7],
#  'Annotator_487': [39, 10],
#  'Annotator_488': [37, 12],
#  'Annotator_489': [45, 4],
#  'Annotator_490': [46, 7],
#  'Annotator_491': [49, 4],
#  'Annotator_492': [39, 14],
#  'Annotator_493': [49, 4],
#  'Annotator_494': [50, 3],
#  'Annotator_495': [50, 3],
#  'Annotator_496': [42, 9],
#  'Annotator_497': [47, 4],
#  'Annotator_498': [44, 7],
#  'Annotator_499': [43, 8],
#  'Annotator_500': [47, 4],
#  'Annotator_501': [45, 6],
#  'Annotator_502': [44, 8],
#  'Annotator_503': [48, 4],
#  'Annotator_504': [42, 10],
#  'Annotator_505': [48, 4],
#  'Annotator_506': [46, 6],
#  'Annotator_507': [36, 16],
#  'Annotator_508': [46, 8],
#  'Annotator_509': [49, 5],
#  'Annotator_510': [47, 7],
#  'Annotator_511': [49, 5],
#  'Annotator_512': [49, 5],
#  'Annotator_513': [49, 5],
#  'Annotator_514': [46, 6],
#  'Annotator_515': [44, 8],
#  'Annotator_516': [50, 2],
#  'Annotator_517': [41, 11],
#  'Annotator_518': [44, 8],
#  'Annotator_519': [47, 5],
#  'Annotator_520': [47, 4],
#  'Annotator_521': [48, 3],
#  'Annotator_522': [46, 5],
#  'Annotator_523': [42, 9],
#  'Annotator_524': [38, 13],
#  'Annotator_525': [44, 5],
#  'Annotator_526': [44, 5],
#  'Annotator_527': [27, 22],
#  'Annotator_528': [44, 5],
#  'Annotator_529': [44, 5],
#  'Annotator_530': [45, 4],
#  'Annotator_531': [43, 9],
#  'Annotator_532': [49, 3],
#  'Annotator_533': [44, 8],
#  'Annotator_534': [47, 5],
#  'Annotator_535': [42, 10],
#  'Annotator_536': [43, 9],
#  'Annotator_537': [48, 6],
#  'Annotator_538': [45, 9],
#  'Annotator_539': [51, 3],
#  'Annotator_540': [45, 9],
#  'Annotator_541': [48, 6],
#  'Annotator_542': [42, 12],
#  'Annotator_543': [48, 7],
#  'Annotator_544': [43, 12],
#  'Annotator_545': [49, 6],
#  'Annotator_546': [50, 5],
#  'Annotator_547': [48, 7],
#  'Annotator_548': [43, 12],
#  'Annotator_549': [41, 10],
#  'Annotator_550': [42, 9],
#  'Annotator_551': [40, 11],
#  'Annotator_552': [43, 8],
#  'Annotator_553': [45, 6],
#  'Annotator_554': [38, 13],
#  'Annotator_555': [32, 10],
#  'Annotator_556': [32, 10],
#  'Annotator_557': [34, 8],
#  'Annotator_558': [30, 12],
#  'Annotator_559': [34, 8],
#  'Annotator_560': [30, 12],
#  'Annotator_561': [47, 6],
#  'Annotator_562': [50, 3],
#  'Annotator_563': [46, 7],
#  'Annotator_564': [42, 11],
#  'Annotator_565': [46, 7],
#  'Annotator_566': [45, 8],
#  'Annotator_567': [47, 3],
#  'Annotator_568': [45, 5],
#  'Annotator_569': [44, 6],
#  'Annotator_570': [42, 8],
#  'Annotator_571': [40, 10],
#  'Annotator_572': [46, 3],
#  'Annotator_573': [47, 2],
#  'Annotator_574': [43, 6],
#  'Annotator_575': [45, 4],
#  'Annotator_576': [37, 12],
#  'Annotator_577': [39, 10],
#  'Annotator_578': [45, 9],
#  'Annotator_579': [47, 7],
#  'Annotator_580': [48, 6],
#  'Annotator_581': [42, 12],
#  'Annotator_582': [41, 13],
#  'Annotator_583': [50, 4],
#  'Annotator_584': [44, 6],
#  'Annotator_585': [46, 4],
#  'Annotator_586': [42, 8],
#  'Annotator_587': [45, 5],
#  'Annotator_588': [42, 8],
#  'Annotator_589': [33, 17],
#  'Annotator_590': [42, 8],
#  'Annotator_591': [44, 6],
#  'Annotator_592': [34, 16],
#  'Annotator_593': [43, 7],
#  'Annotator_594': [44, 6],
#  'Annotator_595': [47, 3],
#  'Annotator_596': [44, 4],
#  'Annotator_597': [42, 6],
#  'Annotator_598': [39, 9],
#  'Annotator_599': [47, 5],
#  'Annotator_600': [47, 5],
#  'Annotator_601': [48, 4],
#  'Annotator_602': [49, 3],
#  'Annotator_603': [41, 11],
#  'Annotator_604': [45, 7],
#  'Annotator_605': [38, 10],
#  'Annotator_606': [40, 8],
#  'Annotator_607': [42, 6],
#  'Annotator_608': [28, 20],
#  'Annotator_609': [35, 13],
#  'Annotator_610': [42, 6],
#  'Annotator_611': [51, 5],
#  'Annotator_612': [43, 13],
#  'Annotator_613': [48, 8],
#  'Annotator_614': [49, 7],
#  'Annotator_615': [44, 12],
#  'Annotator_616': [48, 8],
#  'Annotator_617': [22, 23],
#  'Annotator_618': [39, 6],
#  'Annotator_619': [35, 10],
#  'Annotator_620': [39, 6],
#  'Annotator_621': [36, 9],
#  'Annotator_622': [40, 5],
#  'Annotator_623': [49, 1],
#  'Annotator_624': [40, 10],
#  'Annotator_625': [39, 11],
#  'Annotator_626': [46, 4],
#  'Annotator_627': [45, 5],
#  'Annotator_628': [47, 3],
#  'Annotator_629': [45, 5],
#  'Annotator_630': [40, 10],
#  'Annotator_631': [41, 9],
#  'Annotator_632': [39, 11],
#  'Annotator_633': [40, 10],
#  'Annotator_634': [45, 5],
#  'Annotator_635': [46, 5],
#  'Annotator_636': [42, 9],
#  'Annotator_637': [47, 4],
#  'Annotator_638': [41, 10],
#  'Annotator_639': [46, 3],
#  'Annotator_640': [39, 10],
#  'Annotator_641': [41, 8],
#  'Annotator_642': [40, 9],
#  'Annotator_643': [33, 16],
#  'Annotator_644': [45, 4],
#  'Annotator_645': [45, 6],
#  'Annotator_646': [47, 4],
#  'Annotator_647': [42, 9],
#  'Annotator_648': [30, 21],
#  'Annotator_649': [37, 14],
#  'Annotator_650': [46, 5],
#  'Annotator_651': [42, 9],
#  'Annotator_652': [43, 8],
#  'Annotator_653': [43, 8],
#  'Annotator_654': [38, 13],
#  'Annotator_655': [42, 9],
#  'Annotator_656': [48, 3],
#  'Annotator_657': [46, 5],
#  'Annotator_658': [49, 2],
#  'Annotator_659': [50, 1],
#  'Annotator_660': [48, 3],
#  'Annotator_661': [48, 3],
#  'Annotator_662': [43, 10],
#  'Annotator_663': [47, 6],
#  'Annotator_664': [42, 11],
#  'Annotator_665': [45, 8],
#  'Annotator_666': [44, 9],
#  'Annotator_667': [48, 5],
#  'Annotator_668': [43, 8],
#  'Annotator_669': [47, 4],
#  'Annotator_670': [37, 14],
#  'Annotator_671': [42, 9],
#  'Annotator_672': [44, 7],
#  'Annotator_673': [41, 10],
#  'Annotator_674': [45, 5],
#  'Annotator_675': [43, 7],
#  'Annotator_676': [44, 6],
#  'Annotator_677': [43, 7],
#  'Annotator_678': [43, 7],
#  'Annotator_679': [45, 5],
#  'Annotator_680': [39, 11],
#  'Annotator_681': [38, 12],
#  'Annotator_682': [43, 7],
#  'Annotator_683': [43, 7],
#  'Annotator_684': [43, 7],
#  'Annotator_685': [30, 20],
#  'Annotator_686': [11, 0],
#  'Annotator_687': [8, 3],
#  'Annotator_688': [10, 1],
#  'Annotator_689': [9, 2],
#  'Annotator_690': [9, 2],
#  'Annotator_691': [45, 4],
#  'Annotator_692': [43, 6],
#  'Annotator_693': [44, 5],
#  'Annotator_694': [41, 8],
#  'Annotator_695': [39, 10],
#  'Annotator_696': [43, 6],
#  'Annotator_697': [45, 1],
#  'Annotator_698': [42, 4],
#  'Annotator_699': [43, 3],
#  'Annotator_700': [20, 26],
#  'Annotator_701': [41, 5],
#  'Annotator_702': [41, 5],
#  'Annotator_703': [42, 7],
#  'Annotator_704': [44, 5],
#  'Annotator_705': [40, 9],
#  'Annotator_706': [42, 7],
#  'Annotator_707': [40, 9],
#  'Annotator_708': [42, 7],
#  'Annotator_709': [46, 8],
#  'Annotator_710': [48, 6],
#  'Annotator_711': [47, 7],
#  'Annotator_712': [51, 3],
#  'Annotator_713': [37, 17],
#  'Annotator_714': [40, 9],
#  'Annotator_715': [43, 6],
#  'Annotator_716': [41, 8],
#  'Annotator_717': [39, 10],
#  'Annotator_718': [42, 7],
#  'Annotator_719': [44, 5],
#  'Annotator_720': [41, 9],
#  'Annotator_721': [47, 3],
#  'Annotator_722': [42, 8],
#  'Annotator_723': [43, 7],
#  'Annotator_724': [44, 6],
#  'Annotator_725': [24, 26]}

# %%
Dict_CW_list = list(Dict_CW_new.items())
import numpy as np
Trust_Score = {i[0]: i[1][0]/np.sum(np.array(i[1])) for i in Dict_CW_list}
Trust_Score
# Out:
# {'Annotator_1': 0.75,
#  'Annotator_2': 0.9230769230769231,
#  'Annotator_3': 0.8076923076923077,
#  'Annotator_4': 0.9423076923076923,
#  'Annotator_5': 0.8846153846153846,
#  'Annotator_6': 0.8653846153846154,
#  'Annotator_7': 0.8490566037735849,
#  'Annotator_8': 0.9056603773584906,
#  'Annotator_9': 0.9056603773584906,
#  'Annotator_10': 0.8301886792452831,
#  'Annotator_11': 0.8490566037735849,
#  'Annotator_12': 0.7358490566037735,
#  'Annotator_13': 0.8775510204081632,
#  'Annotator_14': 0.8979591836734694,
#  'Annotator_15': 0.6938775510204082,
#  'Annotator_16': 0.7755102040816326,
#  'Annotator_17': 0.8979591836734694,
#  'Annotator_18': 0.8163265306122449,
#  'Annotator_19': 0.9607843137254902,
#  'Annotator_20': 0.8823529411764706,
#  'Annotator_21': 0.8627450980392157,
#  'Annotator_22': 0.7450980392156863,
#  'Annotator_23': 0.7058823529411765,
#  'Annotator_24': 0.8627450980392157,
#  'Annotator_25': 0.7317073170731707,
#  'Annotator_26': 0.9024390243902439,
#  'Annotator_27': 0.8791208791208791,
#  'Annotator_28': 0.7804878048780488,
#  'Annotator_29': 0.8536585365853658,
#  'Annotator_30': 0.7317073170731707,
#  'Annotator_31': 0.6444444444444445,
#  'Annotator_32': 0.9333333333333333,
#  'Annotator_33': 0.8666666666666667,
#  'Annotator_34': 0.8888888888888888,
#  'Annotator_35': 0.8666666666666667,
#  'Annotator_36': 0.9111111111111111,
#  'Annotator_37': 0.8823529411764706,
#  'Annotator_38': 0.8431372549019608,
#  'Annotator_39': 0.8627450980392157,
#  'Annotator_40': 0.9215686274509803,
#  'Annotator_41': 0.9019607843137255,
#  'Annotator_42': 0.8823529411764706,
#  'Annotator_43': 0.86,
#  'Annotator_44': 0.9230769230769231,
#  'Annotator_45': 0.9230769230769231,
#  'Annotator_46': 0.5961538461538461,
#  'Annotator_47': 0.8269230769230769,
#  'Annotator_48': 0.7115384615384616,
#  'Annotator_49': 0.8541666666666666,
#  'Annotator_50': 0.9583333333333334,
#  'Annotator_51': 0.8333333333333334,
#  'Annotator_52': 0.7708333333333334,
#  'Annotator_53': 0.7916666666666666,
#  'Annotator_54': 0.8125,
#  'Annotator_55': 0.94,
#  'Annotator_56': 0.88,
#  'Annotator_57': 0.86,
#  'Annotator_58': 0.8,
#  'Annotator_59': 0.7,
#  'Annotator_60': 0.84,
#  'Annotator_61': 0.8545454545454545,
#  'Annotator_62': 0.8727272727272727,
#  'Annotator_63': 0.8909090909090909,
#  'Annotator_64': 0.8727272727272727,
#  'Annotator_65': 0.8727272727272727,
#  'Annotator_66': 0.8909090909090909,
#  'Annotator_67': 0.8571428571428571,
#  'Annotator_68': 0.9183673469387755,
#  'Annotator_69': 0.8367346938775511,
#  'Annotator_70': 0.7346938775510204,
#  'Annotator_71': 0.6122448979591837,
#  'Annotator_72': 0.8571428571428571,
#  'Annotator_73': 0.9375,
#  'Annotator_74': 0.7708333333333334,
#  'Annotator_75': 0.9166666666666666,
#  'Annotator_76': 0.75,
#  'Annotator_77': 0.8333333333333334,
#  'Annotator_78': 0.8333333333333334,
#  'Annotator_79': 0.96,
#  'Annotator_80': 0.92,
#  'Annotator_81': 0.92,
#  'Annotator_82': 0.82,
#  'Annotator_83': 0.82,
#  'Annotator_84': 0.76,
#  'Annotator_85': 0.8979591836734694,
#  'Annotator_86': 0.9387755102040817,
#  'Annotator_87': 0.8163265306122449,
#  'Annotator_88': 0.6530612244897959,
#  'Annotator_89': 0.5714285714285714,
#  'Annotator_90': 0.7346938775510204,
#  'Annotator_91': 0.8076923076923077,
#  'Annotator_92': 0.9038461538461539,
#  'Annotator_93': 0.8653846153846154,
#  'Annotator_94': 0.9423076923076923,
#  'Annotator_95': 0.8653846153846154,
#  'Annotator_96': 0.8269230769230769,
#  'Annotator_97': 0.9148936170212766,
#  'Annotator_98': 0.8723404255319149,
#  'Annotator_99': 0.44680851063829785,
#  'Annotator_100': 0.8723404255319149,
#  'Annotator_101': 0.8936170212765957,
#  'Annotator_102': 0.7446808510638298,
#  'Annotator_103': 0.8936170212765957,
#  'Annotator_104': 0.8297872340425532,
#  'Annotator_105': 0.7659574468085106,
#  'Annotator_106': 0.9361702127659575,
#  'Annotator_107': 0.8936170212765957,
#  'Annotator_108': 1.0,
#  'Annotator_109': 0.9056603773584906,
#  'Annotator_110': 0.8490566037735849,
#  'Annotator_111': 0.7547169811320755,
#  'Annotator_112': 0.8867924528301887,
#  'Annotator_113': 0.9245283018867925,
#  'Annotator_114': 0.8490566037735849,
#  'Annotator_115': 0.8333333333333334,
#  'Annotator_116': 0.9583333333333334,
#  'Annotator_117': 0.7474747474747475,
#  'Annotator_118': 0.75,
#  'Annotator_119': 0.875,
#  'Annotator_120': 0.625,
#  'Annotator_121': 0.7391304347826086,
#  'Annotator_122': 0.8913043478260869,
#  'Annotator_123': 0.6086956521739131,
#  'Annotator_124': 0.9130434782608695,
#  'Annotator_125': 0.9130434782608695,
#  'Annotator_126': 0.9347826086956522,
#  'Annotator_127': 0.8909090909090909,
#  'Annotator_128': 0.9090909090909091,
#  'Annotator_129': 0.8545454545454545,
#  'Annotator_130': 0.6886792452830188,
#  'Annotator_131': 1.0,
#  'Annotator_132': 0.9090909090909091,
#  'Annotator_133': 0.9148936170212766,
#  'Annotator_134': 0.9148936170212766,
#  'Annotator_135': 0.8085106382978723,
#  'Annotator_136': 0.8085106382978723,
#  'Annotator_137': 0.9361702127659575,
#  'Annotator_138': 0.8723404255319149,
#  'Annotator_139': 0.88,
#  'Annotator_140': 0.72,
#  'Annotator_141': 0.88,
#  'Annotator_142': 0.8,
#  'Annotator_143': 0.6,
#  'Annotator_144': 0.9,
#  'Annotator_145': 0.7291666666666666,
#  'Annotator_146': 0.7708333333333334,
#  'Annotator_147': 0.8333333333333334,
#  'Annotator_148': 0.875,
#  'Annotator_149': 0.8958333333333334,
#  'Annotator_150': 0.75,
#  'Annotator_151': 0.9245283018867925,
#  'Annotator_152': 0.8301886792452831,
#  'Annotator_153': 0.8301886792452831,
#  'Annotator_154': 0.9433962264150944,
#  'Annotator_155': 0.8490566037735849,
#  'Annotator_156': 0.8679245283018868,
#  'Annotator_157': 0.9574468085106383,
#  'Annotator_158': 0.9148936170212766,
#  'Annotator_159': 0.8723404255319149,
#  'Annotator_160': 0.8297872340425532,
#  'Annotator_161': 0.8085106382978723,
#  'Annotator_162': 0.8936170212765957,
#  'Annotator_163': 0.92,
#  'Annotator_164': 0.88,
#  'Annotator_165': 0.82,
#  'Annotator_166': 0.8,
#  'Annotator_167': 0.86,
#  'Annotator_168': 0.82,
#  'Annotator_169': 0.9166666666666666,
#  'Annotator_170': 0.8541666666666666,
#  'Annotator_171': 0.75,
#  'Annotator_172': 0.8020833333333334,
#  'Annotator_173': 0.9166666666666666,
#  'Annotator_174': 0.8958333333333334,
#  'Annotator_175': 0.8936170212765957,
#  'Annotator_176': 0.9361702127659575,
#  'Annotator_177': 0.9148936170212766,
#  'Annotator_178': 0.7872340425531915,
#  'Annotator_179': 0.8297872340425532,
#  'Annotator_180': 0.8085106382978723,
#  'Annotator_181': 0.9166666666666666,
#  'Annotator_182': 0.9583333333333334,
#  'Annotator_183': 0.9375,
#  'Annotator_184': 0.8541666666666666,
#  'Annotator_185': 0.8958333333333334,
#  'Annotator_186': 0.7916666666666666,
#  'Annotator_187': 0.8155339805825242,
#  'Annotator_188': 0.8076923076923077,
#  'Annotator_189': 0.7692307692307693,
#  'Annotator_190': 0.8431372549019608,
#  'Annotator_191': 0.8846153846153846,
#  'Annotator_192': 0.7884615384615384,
#  'Annotator_193': 0.7708333333333334,
#  'Annotator_194': 0.875,
#  'Annotator_195': 0.7291666666666666,
#  'Annotator_196': 0.9791666666666666,
#  'Annotator_197': 0.875,
#  'Annotator_198': 0.8333333333333334,
#  'Annotator_199': 0.7551020408163265,
#  'Annotator_200': 0.8775510204081632,
#  'Annotator_201': 0.8775510204081632,
#  'Annotator_202': 0.7959183673469388,
#  'Annotator_203': 0.8571428571428571,
#  'Annotator_204': 0.7959183673469388,
#  'Annotator_205': 0.7555555555555555,
#  'Annotator_206': 0.8888888888888888,
#  'Annotator_207': 0.8888888888888888,
#  'Annotator_208': 0.9333333333333333,
#  'Annotator_209': 0.8888888888888888,
#  'Annotator_210': 0.8222222222222222,
#  'Annotator_211': 0.78,
#  'Annotator_212': 0.92,
#  'Annotator_213': 0.82,
#  'Annotator_214': 0.86,
#  'Annotator_215': 0.86,
#  'Annotator_216': 0.78,
#  'Annotator_217': 0.8958333333333334,
#  'Annotator_218': 0.7916666666666666,
#  'Annotator_219': 0.9166666666666666,
#  'Annotator_220': 0.8958333333333334,
#  'Annotator_221': 0.875,
#  'Annotator_222': 0.9166666666666666,
#  'Annotator_223': 0.9183673469387755,
#  'Annotator_224': 0.8163265306122449,
#  'Annotator_225': 0.8367346938775511,
#  'Annotator_226': 0.7142857142857143,
#  'Annotator_227': 0.8571428571428571,
#  'Annotator_228': 0.9591836734693877,
#  'Annotator_229': 0.875,
#  'Annotator_230': 0.9583333333333334,
#  'Annotator_231': 0.8333333333333334,
#  'Annotator_232': 0.4791666666666667,
#  'Annotator_233': 0.8125,
#  'Annotator_234': 0.8958333333333334,
#  'Annotator_235': 0.8846153846153846,
#  'Annotator_236': 0.8846153846153846,
#  'Annotator_237': 0.9038461538461539,
#  'Annotator_238': 0.8076923076923077,
#  'Annotator_239': 0.9038461538461539,
#  'Annotator_240': 0.8461538461538461,
#  'Annotator_241': 0.8823529411764706,
#  'Annotator_242': 0.9019607843137255,
#  'Annotator_243': 0.8235294117647058,
#  'Annotator_244': 0.9607843137254902,
#  'Annotator_245': 0.9019607843137255,
#  'Annotator_246': 0.8627450980392157,
#  'Annotator_247': 0.78,
#  'Annotator_248': 0.92,
#  'Annotator_249': 0.86,
#  'Annotator_250': 0.68,
#  'Annotator_251': 0.84,
#  'Annotator_252': 0.68,
#  'Annotator_253': 0.8823529411764706,
#  'Annotator_254': 0.7058823529411765,
#  'Annotator_255': 0.8431372549019608,
#  'Annotator_256': 0.7254901960784313,
#  'Annotator_257': 0.8431372549019608,
#  'Annotator_258': 0.8627450980392157,
#  'Annotator_259': 0.8163265306122449,
#  'Annotator_260': 0.8571428571428571,
#  'Annotator_261': 0.8775510204081632,
#  'Annotator_262': 0.673469387755102,
#  'Annotator_263': 0.7551020408163265,
#  'Annotator_264': 0.8775510204081632,
#  'Annotator_265': 0.8598130841121495,
#  'Annotator_266': 0.8867924528301887,
#  'Annotator_267': 0.8867924528301887,
#  'Annotator_268': 0.7358490566037735,
#  'Annotator_269': 0.8301886792452831,
#  'Annotator_270': 0.6792452830188679,
#  'Annotator_271': 0.84,
#  'Annotator_272': 0.84,
#  'Annotator_273': 0.76,
#  'Annotator_274': 0.84,
#  'Annotator_275': 0.82,
#  'Annotator_276': 0.88,
#  'Annotator_277': 0.9148936170212766,
#  'Annotator_278': 0.8723404255319149,
#  'Annotator_279': 0.7021276595744681,
#  'Annotator_280': 0.9574468085106383,
#  'Annotator_281': 0.9148936170212766,
#  'Annotator_282': 0.851063829787234,
#  'Annotator_283': 0.9090909090909091,
#  'Annotator_284': 0.9090909090909091,
#  'Annotator_285': 1.0,
#  'Annotator_286': 0.7272727272727273,
#  'Annotator_287': 0.7272727272727273,
#  'Annotator_288': 1.0,
#  'Annotator_289': 0.8490566037735849,
#  'Annotator_290': 0.9056603773584906,
#  'Annotator_291': 0.8113207547169812,
#  'Annotator_292': 0.9622641509433962,
#  'Annotator_293': 0.9056603773584906,
#  'Annotator_294': 0.9245283018867925,
#  'Annotator_295': 0.7735849056603774,
#  'Annotator_296': 0.8,
#  'Annotator_297': 0.8867924528301887,
#  'Annotator_298': 0.7924528301886793,
#  'Annotator_299': 0.7924528301886793,
#  'Annotator_300': 0.9245283018867925,
#  'Annotator_301': 0.88,
#  'Annotator_302': 0.86,
#  'Annotator_303': 0.84,
#  'Annotator_304': 0.86,
#  'Annotator_305': 0.78,
#  'Annotator_306': 0.84,
#  'Annotator_307': 0.8958333333333334,
#  'Annotator_308': 0.8958333333333334,
#  'Annotator_309': 0.9375,
#  'Annotator_310': 0.8333333333333334,
#  'Annotator_311': 0.8333333333333334,
#  'Annotator_312': 0.7916666666666666,
#  'Annotator_313': 0.875,
#  'Annotator_314': 0.8958333333333334,
#  'Annotator_315': 0.8958333333333334,
#  'Annotator_316': 0.9166666666666666,
#  'Annotator_317': 0.75,
#  'Annotator_318': 0.8958333333333334,
#  'Annotator_319': 0.8775510204081632,
#  'Annotator_320': 0.8775510204081632,
#  'Annotator_321': 0.8163265306122449,
#  'Annotator_322': 0.8775510204081632,
#  'Annotator_323': 0.8163265306122449,
#  'Annotator_324': 0.9795918367346939,
#  'Annotator_325': 0.6538461538461539,
#  'Annotator_326': 0.9807692307692307,
#  'Annotator_327': 0.7884615384615384,
#  'Annotator_328': 0.8076923076923077,
#  'Annotator_329': 0.8461538461538461,
#  'Annotator_330': 0.9230769230769231,
#  'Annotator_331': 0.7692307692307693,
#  'Annotator_332': 0.8518518518518519,
#  'Annotator_333': 0.9215686274509803,
#  'Annotator_334': 0.8333333333333334,
#  'Annotator_335': 0.8148148148148148,
#  'Annotator_336': 0.8888888888888888,
#  'Annotator_337': 0.6888888888888889,
#  'Annotator_338': 0.8888888888888888,
#  'Annotator_339': 0.8888888888888888,
#  'Annotator_340': 0.8829787234042553,
#  'Annotator_341': 0.8666666666666667,
#  'Annotator_342': 0.9111111111111111,
#  'Annotator_343': 0.88,
#  'Annotator_344': 0.86,
#  'Annotator_345': 0.9,
#  'Annotator_346': 0.72,
#  'Annotator_347': 0.84,
#  'Annotator_348': 0.82,
#  'Annotator_349': 0.8979591836734694,
#  'Annotator_350': 0.8571428571428571,
#  'Annotator_351': 0.8979591836734694,
#  'Annotator_352': 0.9591836734693877,
#  'Annotator_353': 0.3877551020408163,
#  'Annotator_354': 0.8367346938775511,
#  'Annotator_355': 0.8775510204081632,
#  'Annotator_356': 0.8775510204081632,
#  'Annotator_357': 0.7346938775510204,
#  'Annotator_358': 0.8571428571428571,
#  'Annotator_359': 0.7551020408163265,
#  'Annotator_360': 0.9591836734693877,
#  'Annotator_361': 0.6862745098039216,
#  'Annotator_362': 0.9215686274509803,
#  'Annotator_363': 0.8627450980392157,
#  'Annotator_364': 0.8823529411764706,
#  'Annotator_365': 0.8823529411764706,
#  'Annotator_366': 0.8627450980392157,
#  'Annotator_367': 0.8653846153846154,
#  'Annotator_368': 0.8076923076923077,
#  'Annotator_369': 0.8269230769230769,
#  'Annotator_370': 0.8846153846153846,
#  'Annotator_371': 0.9230769230769231,
#  'Annotator_372': 0.9230769230769231,
#  'Annotator_373': 0.8909090909090909,
#  'Annotator_374': 0.9272727272727272,
#  'Annotator_375': 0.7818181818181819,
#  'Annotator_376': 0.8727272727272727,
#  'Annotator_377': 0.9090909090909091,
#  'Annotator_378': 0.9454545454545454,
#  'Annotator_379': 0.9019607843137255,
#  'Annotator_380': 0.6666666666666666,
#  'Annotator_381': 0.8431372549019608,
#  'Annotator_382': 0.6666666666666666,
#  'Annotator_383': 0.9215686274509803,
#  'Annotator_384': 0.803921568627451,
#  'Annotator_385': 0.8942307692307693,
#  'Annotator_386': 0.9433962264150944,
#  'Annotator_387': 0.8867924528301887,
#  'Annotator_388': 0.8679245283018868,
#  'Annotator_389': 0.8113207547169812,
#  'Annotator_390': 0.8679245283018868,
#  'Annotator_391': 0.9183673469387755,
#  'Annotator_392': 0.8775510204081632,
#  'Annotator_393': 0.9183673469387755,
#  'Annotator_394': 0.8163265306122449,
#  'Annotator_395': 0.8367346938775511,
#  'Annotator_396': 0.8979591836734694,
#  'Annotator_397': 0.84,
#  'Annotator_398': 0.92,
#  'Annotator_399': 0.8,
#  'Annotator_400': 0.96,
#  'Annotator_401': 0.74,
#  'Annotator_402': 0.8,
#  'Annotator_403': 0.8775510204081632,
#  'Annotator_404': 0.8367346938775511,
#  'Annotator_405': 0.8775510204081632,
#  'Annotator_406': 0.8571428571428571,
#  'Annotator_407': 0.8571428571428571,
#  'Annotator_408': 0.8367346938775511,
#  'Annotator_409': 0.9375,
#  'Annotator_410': 0.8333333333333334,
#  'Annotator_411': 0.875,
#  'Annotator_412': 0.8333333333333334,
#  'Annotator_413': 0.8958333333333334,
#  'Annotator_414': 0.5833333333333334,
#  'Annotator_415': 0.8571428571428571,
#  'Annotator_416': 0.9183673469387755,
#  'Annotator_417': 0.7959183673469388,
#  'Annotator_418': 0.8775510204081632,
#  'Annotator_419': 0.8571428571428571,
#  'Annotator_420': 0.9230769230769231,
#  'Annotator_421': 0.7692307692307693,
#  'Annotator_422': 0.9038461538461539,
#  'Annotator_423': 0.8846153846153846,
#  'Annotator_424': 0.8846153846153846,
#  'Annotator_425': 0.8163265306122449,
#  'Annotator_426': 0.9183673469387755,
#  'Annotator_427': 0.8775510204081632,
#  'Annotator_428': 0.8367346938775511,
#  'Annotator_429': 0.8775510204081632,
#  'Annotator_430': 0.8571428571428571,
#  'Annotator_431': 0.8297872340425532,
#  'Annotator_432': 0.8936170212765957,
#  'Annotator_433': 0.851063829787234,
#  'Annotator_434': 0.8936170212765957,
#  'Annotator_435': 0.8085106382978723,
#  'Annotator_436': 0.8936170212765957,
#  'Annotator_437': 0.8979591836734694,
#  'Annotator_438': 0.7755102040816326,
#  'Annotator_439': 0.9387755102040817,
#  'Annotator_440': 0.7755102040816326,
#  'Annotator_441': 0.8775510204081632,
#  'Annotator_442': 1.0,
#  'Annotator_443': 0.8478260869565217,
#  'Annotator_444': 0.8260869565217391,
#  'Annotator_445': 0.5434782608695652,
#  'Annotator_446': 0.8913043478260869,
#  'Annotator_447': 0.9130434782608695,
#  'Annotator_448': 0.8913043478260869,
#  'Annotator_449': 0.92,
#  'Annotator_450': 0.8,
#  'Annotator_451': 0.74,
#  'Annotator_452': 0.84,
#  'Annotator_453': 0.92,
#  'Annotator_454': 0.7,
#  'Annotator_455': 0.6666666666666666,
#  'Annotator_456': 0.7843137254901961,
#  'Annotator_457': 0.803921568627451,
#  'Annotator_458': 0.9215686274509803,
#  'Annotator_459': 0.8431372549019608,
#  'Annotator_460': 0.8235294117647058,
#  'Annotator_461': 0.8653846153846154,
#  'Annotator_462': 0.7884615384615384,
#  'Annotator_463': 0.8461538461538461,
#  'Annotator_464': 0.8653846153846154,
#  'Annotator_465': 0.8269230769230769,
#  'Annotator_466': 0.8846153846153846,
#  'Annotator_467': 0.8571428571428571,
#  'Annotator_468': 0.8775510204081632,
#  'Annotator_469': 0.8367346938775511,
#  'Annotator_470': 0.8571428571428571,
#  'Annotator_471': 0.8571428571428571,
#  'Annotator_472': 0.9183673469387755,
#  'Annotator_473': 0.88,
#  'Annotator_474': 0.82,
#  'Annotator_475': 0.9,
#  'Annotator_476': 0.72,
#  'Annotator_477': 0.9,
#  'Annotator_478': 0.8444444444444444,
#  'Annotator_479': 0.8666666666666667,
#  'Annotator_480': 0.7555555555555555,
#  'Annotator_481': 0.7777777777777778,
#  'Annotator_482': 0.8888888888888888,
#  'Annotator_483': 0.9111111111111111,
#  'Annotator_484': 0.8775510204081632,
#  'Annotator_485': 0.9183673469387755,
#  'Annotator_486': 0.8571428571428571,
#  'Annotator_487': 0.7959183673469388,
#  'Annotator_488': 0.7551020408163265,
#  'Annotator_489': 0.9183673469387755,
#  'Annotator_490': 0.8679245283018868,
#  'Annotator_491': 0.9245283018867925,
#  'Annotator_492': 0.7358490566037735,
#  'Annotator_493': 0.9245283018867925,
#  'Annotator_494': 0.9433962264150944,
#  'Annotator_495': 0.9433962264150944,
#  'Annotator_496': 0.8235294117647058,
#  'Annotator_497': 0.9215686274509803,
#  'Annotator_498': 0.8627450980392157,
#  'Annotator_499': 0.8431372549019608,
#  'Annotator_500': 0.9215686274509803,
#  'Annotator_501': 0.8823529411764706,
#  'Annotator_502': 0.8461538461538461,
#  'Annotator_503': 0.9230769230769231,
#  'Annotator_504': 0.8076923076923077,
#  'Annotator_505': 0.9230769230769231,
#  'Annotator_506': 0.8846153846153846,
#  'Annotator_507': 0.6923076923076923,
#  'Annotator_508': 0.8518518518518519,
#  'Annotator_509': 0.9074074074074074,
#  'Annotator_510': 0.8703703703703703,
#  'Annotator_511': 0.9074074074074074,
#  'Annotator_512': 0.9074074074074074,
#  'Annotator_513': 0.9074074074074074,
#  'Annotator_514': 0.8846153846153846,
#  'Annotator_515': 0.8461538461538461,
#  'Annotator_516': 0.9615384615384616,
#  'Annotator_517': 0.7884615384615384,
#  'Annotator_518': 0.8461538461538461,
#  'Annotator_519': 0.9038461538461539,
#  'Annotator_520': 0.9215686274509803,
#  'Annotator_521': 0.9411764705882353,
#  'Annotator_522': 0.9019607843137255,
#  'Annotator_523': 0.8235294117647058,
#  'Annotator_524': 0.7450980392156863,
#  'Annotator_525': 0.8979591836734694,
#  'Annotator_526': 0.8979591836734694,
#  'Annotator_527': 0.5510204081632653,
#  'Annotator_528': 0.8979591836734694,
#  'Annotator_529': 0.8979591836734694,
#  'Annotator_530': 0.9183673469387755,
#  'Annotator_531': 0.8269230769230769,
#  'Annotator_532': 0.9423076923076923,
#  'Annotator_533': 0.8461538461538461,
#  'Annotator_534': 0.9038461538461539,
#  'Annotator_535': 0.8076923076923077,
#  'Annotator_536': 0.8269230769230769,
#  'Annotator_537': 0.8888888888888888,
#  'Annotator_538': 0.8333333333333334,
#  'Annotator_539': 0.9444444444444444,
#  'Annotator_540': 0.8333333333333334,
#  'Annotator_541': 0.8888888888888888,
#  'Annotator_542': 0.7777777777777778,
#  'Annotator_543': 0.8727272727272727,
#  'Annotator_544': 0.7818181818181819,
#  'Annotator_545': 0.8909090909090909,
#  'Annotator_546': 0.9090909090909091,
#  'Annotator_547': 0.8727272727272727,
#  'Annotator_548': 0.7818181818181819,
#  'Annotator_549': 0.803921568627451,
#  'Annotator_550': 0.8235294117647058,
#  'Annotator_551': 0.7843137254901961,
#  'Annotator_552': 0.8431372549019608,
#  'Annotator_553': 0.8823529411764706,
#  'Annotator_554': 0.7450980392156863,
#  'Annotator_555': 0.7619047619047619,
#  'Annotator_556': 0.7619047619047619,
#  'Annotator_557': 0.8095238095238095,
#  'Annotator_558': 0.7142857142857143,
#  'Annotator_559': 0.8095238095238095,
#  'Annotator_560': 0.7142857142857143,
#  'Annotator_561': 0.8867924528301887,
#  'Annotator_562': 0.9433962264150944,
#  'Annotator_563': 0.8679245283018868,
#  'Annotator_564': 0.7924528301886793,
#  'Annotator_565': 0.8679245283018868,
#  'Annotator_566': 0.8490566037735849,
#  'Annotator_567': 0.94,
#  'Annotator_568': 0.9,
#  'Annotator_569': 0.88,
#  'Annotator_570': 0.84,
#  'Annotator_571': 0.8,
#  'Annotator_572': 0.9387755102040817,
#  'Annotator_573': 0.9591836734693877,
#  'Annotator_574': 0.8775510204081632,
#  'Annotator_575': 0.9183673469387755,
#  'Annotator_576': 0.7551020408163265,
#  'Annotator_577': 0.7959183673469388,
#  'Annotator_578': 0.8333333333333334,
#  'Annotator_579': 0.8703703703703703,
#  'Annotator_580': 0.8888888888888888,
#  'Annotator_581': 0.7777777777777778,
#  'Annotator_582': 0.7592592592592593,
#  'Annotator_583': 0.9259259259259259,
#  'Annotator_584': 0.88,
#  'Annotator_585': 0.92,
#  'Annotator_586': 0.84,
#  'Annotator_587': 0.9,
#  'Annotator_588': 0.84,
#  'Annotator_589': 0.66,
#  'Annotator_590': 0.84,
#  'Annotator_591': 0.88,
#  'Annotator_592': 0.68,
#  'Annotator_593': 0.86,
#  'Annotator_594': 0.88,
#  'Annotator_595': 0.94,
#  'Annotator_596': 0.9166666666666666,
#  'Annotator_597': 0.875,
#  'Annotator_598': 0.8125,
#  'Annotator_599': 0.9038461538461539,
#  'Annotator_600': 0.9038461538461539,
#  'Annotator_601': 0.9230769230769231,
#  'Annotator_602': 0.9423076923076923,
#  'Annotator_603': 0.7884615384615384,
#  'Annotator_604': 0.8653846153846154,
#  'Annotator_605': 0.7916666666666666,
#  'Annotator_606': 0.8333333333333334,
#  'Annotator_607': 0.875,
#  'Annotator_608': 0.5833333333333334,
#  'Annotator_609': 0.7291666666666666,
#  'Annotator_610': 0.875,
#  'Annotator_611': 0.9107142857142857,
#  'Annotator_612': 0.7678571428571429,
#  'Annotator_613': 0.8571428571428571,
#  'Annotator_614': 0.875,
#  'Annotator_615': 0.7857142857142857,
#  'Annotator_616': 0.8571428571428571,
#  'Annotator_617': 0.4888888888888889,
#  'Annotator_618': 0.8666666666666667,
#  'Annotator_619': 0.7777777777777778,
#  'Annotator_620': 0.8666666666666667,
#  'Annotator_621': 0.8,
#  'Annotator_622': 0.8888888888888888,
#  'Annotator_623': 0.98,
#  'Annotator_624': 0.8,
#  'Annotator_625': 0.78,
#  'Annotator_626': 0.92,
#  'Annotator_627': 0.9,
#  'Annotator_628': 0.94,
#  'Annotator_629': 0.9,
#  'Annotator_630': 0.8,
#  'Annotator_631': 0.82,
#  'Annotator_632': 0.78,
#  'Annotator_633': 0.8,
#  'Annotator_634': 0.9,
#  'Annotator_635': 0.9019607843137255,
#  'Annotator_636': 0.8235294117647058,
#  'Annotator_637': 0.9215686274509803,
#  'Annotator_638': 0.803921568627451,
#  'Annotator_639': 0.9387755102040817,
#  'Annotator_640': 0.7959183673469388,
#  'Annotator_641': 0.8367346938775511,
#  'Annotator_642': 0.8163265306122449,
#  'Annotator_643': 0.673469387755102,
#  'Annotator_644': 0.9183673469387755,
#  'Annotator_645': 0.8823529411764706,
#  'Annotator_646': 0.9215686274509803,
#  'Annotator_647': 0.8235294117647058,
#  'Annotator_648': 0.5882352941176471,
#  'Annotator_649': 0.7254901960784313,
#  'Annotator_650': 0.9019607843137255,
#  'Annotator_651': 0.8235294117647058,
#  'Annotator_652': 0.8431372549019608,
#  'Annotator_653': 0.8431372549019608,
#  'Annotator_654': 0.7450980392156863,
#  'Annotator_655': 0.8235294117647058,
#  'Annotator_656': 0.9411764705882353,
#  'Annotator_657': 0.9019607843137255,
#  'Annotator_658': 0.9607843137254902,
#  'Annotator_659': 0.9803921568627451,
#  'Annotator_660': 0.9411764705882353,
#  'Annotator_661': 0.9411764705882353,
#  'Annotator_662': 0.8113207547169812,
#  'Annotator_663': 0.8867924528301887,
#  'Annotator_664': 0.7924528301886793,
#  'Annotator_665': 0.8490566037735849,
#  'Annotator_666': 0.8301886792452831,
#  'Annotator_667': 0.9056603773584906,
#  'Annotator_668': 0.8431372549019608,
#  'Annotator_669': 0.9215686274509803,
#  'Annotator_670': 0.7254901960784313,
#  'Annotator_671': 0.8235294117647058,
#  'Annotator_672': 0.8627450980392157,
#  'Annotator_673': 0.803921568627451,
#  'Annotator_674': 0.9,
#  'Annotator_675': 0.86,
#  'Annotator_676': 0.88,
#  'Annotator_677': 0.86,
#  'Annotator_678': 0.86,
#  'Annotator_679': 0.9,
#  'Annotator_680': 0.78,
#  'Annotator_681': 0.76,
#  'Annotator_682': 0.86,
#  'Annotator_683': 0.86,
#  'Annotator_684': 0.86,
#  'Annotator_685': 0.6,
#  'Annotator_686': 1.0,
#  'Annotator_687': 0.7272727272727273,
#  'Annotator_688': 0.9090909090909091,
#  'Annotator_689': 0.8181818181818182,
#  'Annotator_690': 0.8181818181818182,
#  'Annotator_691': 0.9183673469387755,
#  'Annotator_692': 0.8775510204081632,
#  'Annotator_693': 0.8979591836734694,
#  'Annotator_694': 0.8367346938775511,
#  'Annotator_695': 0.7959183673469388,
#  'Annotator_696': 0.8775510204081632,
#  'Annotator_697': 0.9782608695652174,
#  'Annotator_698': 0.9130434782608695,
#  'Annotator_699': 0.9347826086956522,
#  'Annotator_700': 0.43478260869565216,
#  'Annotator_701': 0.8913043478260869,
#  'Annotator_702': 0.8913043478260869,
#  'Annotator_703': 0.8571428571428571,
#  'Annotator_704': 0.8979591836734694,
#  'Annotator_705': 0.8163265306122449,
#  'Annotator_706': 0.8571428571428571,
#  'Annotator_707': 0.8163265306122449,
#  'Annotator_708': 0.8571428571428571,
#  'Annotator_709': 0.8518518518518519,
#  'Annotator_710': 0.8888888888888888,
#  'Annotator_711': 0.8703703703703703,
#  'Annotator_712': 0.9444444444444444,
#  'Annotator_713': 0.6851851851851852,
#  'Annotator_714': 0.8163265306122449,
#  'Annotator_715': 0.8775510204081632,
#  'Annotator_716': 0.8367346938775511,
#  'Annotator_717': 0.7959183673469388,
#  'Annotator_718': 0.8571428571428571,
#  'Annotator_719': 0.8979591836734694,
#  'Annotator_720': 0.82,
#  'Annotator_721': 0.94,
#  'Annotator_722': 0.84,
#  'Annotator_723': 0.86,
#  'Annotator_724': 0.88,
#  'Annotator_725': 0.48}

# %%
#find annotator age group

annotators_column = df.annotators.to_numpy().flatten().tolist()
age_column = df.age_annotators.to_numpy().flatten().tolist()
Dict_ann_age = {}
for (i, ans) in enumerate(annotators_column):
    for (j, individual) in enumerate(ans):
        if Dict_ann_age.get(age_column[i][j]) is None:
            Dict_ann_age[age_column[i][j]] = [individual]
        else:
            if individual not in Dict_ann_age[age_column[i][j]]:
                Dict_ann_age[age_column[i][j]].append(individual)

Dict_ann_age
# Out:
# {'18-22': ['Annotator_1',
#   'Annotator_6',
#   'Annotator_7',
#   'Annotator_12',
#   'Annotator_13',
#   'Annotator_18',
#   'Annotator_19',
#   'Annotator_24',
#   'Annotator_25',
#   'Annotator_30',
#   'Annotator_31',
#   'Annotator_36',
#   'Annotator_37',
#   'Annotator_42',
#   'Annotator_43',
#   'Annotator_48',
#   'Annotator_49',
#   'Annotator_54',
#   'Annotator_55',
#   'Annotator_60',
#   'Annotator_61',
#   'Annotator_66',
#   'Annotator_67',
#   'Annotator_72',
#   'Annotator_73',
#   'Annotator_78',
#   'Annotator_79',
#   'Annotator_84',
#   'Annotator_85',
#   'Annotator_90',
#   'Annotator_91',
#   'Annotator_96',
#   'Annotator_97',
#   'Annotator_102',
#   'Annotator_103',
#   'Annotator_108',
#   'Annotator_109',
#   'Annotator_114',
#   'Annotator_115',
#   'Annotator_120',
#   'Annotator_121',
#   'Annotator_126',
#   'Annotator_127',
#   'Annotator_132',
#   'Annotator_133',
#   'Annotator_138',
#   'Annotator_139',
#   'Annotator_144',
#   'Annotator_145',
#   'Annotator_150',
#   'Annotator_151',
#   'Annotator_156',
#   'Annotator_157',
#   'Annotator_162',
#   'Annotator_163',
#   'Annotator_168',
#   'Annotator_169',
#   'Annotator_174',
#   'Annotator_175',
#   'Annotator_180',
#   'Annotator_181',
#   'Annotator_186',
#   'Annotator_187',
#   'Annotator_192',
#   'Annotator_193',
#   'Annotator_198',
#   'Annotator_199',
#   'Annotator_204',
#   'Annotator_205',
#   'Annotator_210',
#   'Annotator_211',
#   'Annotator_216',
#   'Annotator_217',
#   'Annotator_222',
#   'Annotator_223',
#   'Annotator_228',
#   'Annotator_229',
#   'Annotator_234',
#   'Annotator_235',
#   'Annotator_240',
#   'Annotator_241',
#   'Annotator_246',
#   'Annotator_247',
#   'Annotator_252',
#   'Annotator_253',
#   'Annotator_258',
#   'Annotator_259',
#   'Annotator_264',
#   'Annotator_265',
#   'Annotator_270',
#   'Annotator_271',
#   'Annotator_276',
#   'Annotator_277',
#   'Annotator_282',
#   'Annotator_283',
#   'Annotator_288',
#   'Annotator_289',
#   'Annotator_294',
#   'Annotator_295',
#   'Annotator_300',
#   'Annotator_301',
#   'Annotator_306',
#   'Annotator_307',
#   'Annotator_312',
#   'Annotator_313',
#   'Annotator_318',
#   'Annotator_319',
#   'Annotator_324',
#   'Annotator_325',
#   'Annotator_330',
#   'Annotator_331',
#   'Annotator_336',
#   'Annotator_337',
#   'Annotator_342',
#   'Annotator_343',
#   'Annotator_348',
#   'Annotator_349',
#   'Annotator_354',
#   'Annotator_355',
#   'Annotator_360',
#   'Annotator_361',
#   'Annotator_366',
#   'Annotator_367',
#   'Annotator_372',
#   'Annotator_373',
#   'Annotator_378',
#   'Annotator_379',
#   'Annotator_384',
#   'Annotator_385',
#   'Annotator_390',
#   'Annotator_391',
#   'Annotator_393',
#   'Annotator_397',
#   'Annotator_399',
#   'Annotator_403',
#   'Annotator_405',
#   'Annotator_409',
#   'Annotator_411',
#   'Annotator_415',
#   'Annotator_417',
#   'Annotator_420',
#   'Annotator_421',
#   'Annotator_425',
#   'Annotator_427',
#   'Annotator_431',
#   'Annotator_433',
#   'Annotator_437',
#   'Annotator_439',
#   'Annotator_443',
#   'Annotator_445',
#   'Annotator_449',
#   'Annotator_451',
#   'Annotator_455',
#   'Annotator_457',
#   'Annotator_461',
#   'Annotator_463',
#   'Annotator_467',
#   'Annotator_469',
#   'Annotator_473',
#   'Annotator_475',
#   'Annotator_478',
#   'Annotator_480',
#   'Annotator_484',
#   'Annotator_486',
#   'Annotator_490',
#   'Annotator_492',
#   'Annotator_496',
#   'Annotator_498',
#   'Annotator_502',
#   'Annotator_504',
#   'Annotator_508',
#   'Annotator_510',
#   'Annotator_514',
#   'Annotator_516',
#   'Annotator_520',
#   'Annotator_522',
#   'Annotator_525',
#   'Annotator_527',
#   'Annotator_531',
#   'Annotator_533',
#   'Annotator_537',
#   'Annotator_539',
#   'Annotator_543',
#   'Annotator_545',
#   'Annotator_549',
#   'Annotator_551',
#   'Annotator_555',
#   'Annotator_557',
#   'Annotator_561',
#   'Annotator_563',
#   'Annotator_567',
#   'Annotator_569',
#   'Annotator_572',
#   'Annotator_574',
#   'Annotator_578',
#   'Annotator_580',
#   'Annotator_584',
#   'Annotator_586',
#   'Annotator_590',
#   'Annotator_592',
#   'Annotator_597',
#   'Annotator_599',
#   'Annotator_601',
#   'Annotator_605',
#   'Annotator_607',
#   'Annotator_611',
#   'Annotator_613',
#   'Annotator_617',
#   'Annotator_619',
#   'Annotator_623',
#   'Annotator_625',
#   'Annotator_629',
#   'Annotator_631',
#   'Annotator_636',
#   'Annotator_639',
#   'Annotator_641',
#   'Annotator_645',
#   'Annotator_647',
#   'Annotator_651',
#   'Annotator_653',
#   'Annotator_658',
#   'Annotator_662',
#   'Annotator_664',
#   'Annotator_668',
#   'Annotator_670',
#   'Annotator_674',
#   'Annotator_676',
#   'Annotator_680',
#   'Annotator_682',
#   'Annotator_687',
#   'Annotator_691',
#   'Annotator_693',
#   'Annotator_697',
#   'Annotator_699',
#   'Annotator_703',
#   'Annotator_705',
#   'Annotator_710',
#   'Annotator_714',
#   'Annotator_716',
#   'Annotator_720',
#   'Annotator_722'],
#  '23-45': ['Annotator_2',
#   'Annotator_5',
#   'Annotator_8',
#   'Annotator_11',
#   'Annotator_14',
#   'Annotator_17',
#   'Annotator_20',
#   'Annotator_23',
#   'Annotator_26',
#   'Annotator_29',
#   'Annotator_32',
#   'Annotator_35',
#   'Annotator_38',
#   'Annotator_41',
#   'Annotator_44',
#   'Annotator_47',
#   'Annotator_50',
#   'Annotator_53',
#   'Annotator_56',
#   'Annotator_59',
#   'Annotator_62',
#   'Annotator_65',
#   'Annotator_68',
#   'Annotator_71',
#   'Annotator_74',
#   'Annotator_77',
#   'Annotator_80',
#   'Annotator_83',
#   'Annotator_86',
#   'Annotator_89',
#   'Annotator_92',
#   'Annotator_95',
#   'Annotator_98',
#   'Annotator_101',
#   'Annotator_104',
#   'Annotator_107',
#   'Annotator_110',
#   'Annotator_113',
#   'Annotator_116',
#   'Annotator_119',
#   'Annotator_122',
#   'Annotator_125',
#   'Annotator_128',
#   'Annotator_131',
#   'Annotator_134',
#   'Annotator_137',
#   'Annotator_140',
#   'Annotator_143',
#   'Annotator_146',
#   'Annotator_149',
#   'Annotator_152',
#   'Annotator_155',
#   'Annotator_158',
#   'Annotator_161',
#   'Annotator_164',
#   'Annotator_167',
#   'Annotator_170',
#   'Annotator_173',
#   'Annotator_176',
#   'Annotator_179',
#   'Annotator_182',
#   'Annotator_185',
#   'Annotator_188',
#   'Annotator_191',
#   'Annotator_194',
#   'Annotator_197',
#   'Annotator_200',
#   'Annotator_203',
#   'Annotator_206',
#   'Annotator_209',
#   'Annotator_212',
#   'Annotator_215',
#   'Annotator_218',
#   'Annotator_221',
#   'Annotator_224',
#   'Annotator_227',
#   'Annotator_230',
#   'Annotator_233',
#   'Annotator_236',
#   'Annotator_239',
#   'Annotator_242',
#   'Annotator_245',
#   'Annotator_248',
#   'Annotator_251',
#   'Annotator_254',
#   'Annotator_257',
#   'Annotator_260',
#   'Annotator_263',
#   'Annotator_266',
#   'Annotator_269',
#   'Annotator_272',
#   'Annotator_275',
#   'Annotator_278',
#   'Annotator_281',
#   'Annotator_284',
#   'Annotator_287',
#   'Annotator_290',
#   'Annotator_293',
#   'Annotator_296',
#   'Annotator_299',
#   'Annotator_302',
#   'Annotator_305',
#   'Annotator_308',
#   'Annotator_311',
#   'Annotator_314',
#   'Annotator_317',
#   'Annotator_320',
#   'Annotator_323',
#   'Annotator_326',
#   'Annotator_329',
#   'Annotator_332',
#   'Annotator_335',
#   'Annotator_338',
#   'Annotator_341',
#   'Annotator_344',
#   'Annotator_347',
#   'Annotator_350',
#   'Annotator_353',
#   'Annotator_356',
#   'Annotator_359',
#   'Annotator_362',
#   'Annotator_365',
#   'Annotator_368',
#   'Annotator_371',
#   'Annotator_374',
#   'Annotator_377',
#   'Annotator_380',
#   'Annotator_383',
#   'Annotator_386',
#   'Annotator_389',
#   'Annotator_392',
#   'Annotator_394',
#   'Annotator_398',
#   'Annotator_400',
#   'Annotator_404',
#   'Annotator_406',
#   'Annotator_410',
#   'Annotator_412',
#   'Annotator_416',
#   'Annotator_418',
#   'Annotator_422',
#   'Annotator_426',
#   'Annotator_428',
#   'Annotator_432',
#   'Annotator_434',
#   'Annotator_438',
#   'Annotator_440',
#   'Annotator_444',
#   'Annotator_446',
#   'Annotator_450',
#   'Annotator_452',
#   'Annotator_456',
#   'Annotator_458',
#   'Annotator_462',
#   'Annotator_464',
#   'Annotator_468',
#   'Annotator_470',
#   'Annotator_474',
#   'Annotator_476',
#   'Annotator_479',
#   'Annotator_481',
#   'Annotator_485',
#   'Annotator_487',
#   'Annotator_491',
#   'Annotator_493',
#   'Annotator_497',
#   'Annotator_499',
#   'Annotator_503',
#   'Annotator_505',
#   'Annotator_509',
#   'Annotator_511',
#   'Annotator_515',
#   'Annotator_517',
#   'Annotator_521',
#   'Annotator_523',
#   'Annotator_526',
#   'Annotator_528',
#   'Annotator_532',
#   'Annotator_534',
#   'Annotator_538',
#   'Annotator_540',
#   'Annotator_544',
#   'Annotator_546',
#   'Annotator_550',
#   'Annotator_552',
#   'Annotator_556',
#   'Annotator_558',
#   'Annotator_562',
#   'Annotator_564',
#   'Annotator_568',
#   'Annotator_570',
#   'Annotator_573',
#   'Annotator_575',
#   'Annotator_579',
#   'Annotator_581',
#   'Annotator_585',
#   'Annotator_587',
#   'Annotator_591',
#   'Annotator_593',
#   'Annotator_596',
#   'Annotator_598',
#   'Annotator_600',
#   'Annotator_602',
#   'Annotator_606',
#   'Annotator_608',
#   'Annotator_612',
#   'Annotator_614',
#   'Annotator_618',
#   'Annotator_620',
#   'Annotator_624',
#   'Annotator_626',
#   'Annotator_630',
#   'Annotator_632',
#   'Annotator_635',
#   'Annotator_637',
#   'Annotator_640',
#   'Annotator_642',
#   'Annotator_646',
#   'Annotator_648',
#   'Annotator_652',
#   'Annotator_654',
#   'Annotator_657',
#   'Annotator_659',
#   'Annotator_663',
#   'Annotator_665',
#   'Annotator_669',
#   'Annotator_671',
#   'Annotator_675',
#   'Annotator_677',
#   'Annotator_681',
#   'Annotator_683',
#   'Annotator_686',
#   'Annotator_688',
#   'Annotator_692',
#   'Annotator_694',
#   'Annotator_698',
#   'Annotator_700',
#   'Annotator_704',
#   'Annotator_706',
#   'Annotator_709',
#   'Annotator_711',
#   'Annotator_715',
#   'Annotator_717',
#   'Annotator_721',
#   'Annotator_723'],
#  '46+': ['Annotator_3',
#   'Annotator_4',
#   'Annotator_9',
#   'Annotator_10',
#   'Annotator_15',
#   'Annotator_16',
#   'Annotator_21',
#   'Annotator_22',
#   'Annotator_27',
#   'Annotator_28',
#   'Annotator_33',
#   'Annotator_34',
#   'Annotator_39',
#   'Annotator_40',
#   'Annotator_45',
#   'Annotator_46',
#   'Annotator_51',
#   'Annotator_52',
#   'Annotator_57',
#   'Annotator_58',
#   'Annotator_63',
#   'Annotator_64',
#   'Annotator_69',
#   'Annotator_70',
#   'Annotator_75',
#   'Annotator_76',
#   'Annotator_81',
#   'Annotator_82',
#   'Annotator_87',
#   'Annotator_88',
#   'Annotator_93',
#   'Annotator_94',
#   'Annotator_99',
#   'Annotator_100',
#   'Annotator_105',
#   'Annotator_106',
#   'Annotator_111',
#   'Annotator_112',
#   'Annotator_117',
#   'Annotator_118',
#   'Annotator_123',
#   'Annotator_124',
#   'Annotator_129',
#   'Annotator_130',
#   'Annotator_135',
#   'Annotator_136',
#   'Annotator_141',
#   'Annotator_142',
#   'Annotator_147',
#   'Annotator_148',
#   'Annotator_153',
#   'Annotator_154',
#   'Annotator_159',
#   'Annotator_160',
#   'Annotator_165',
#   'Annotator_166',
#   'Annotator_171',
#   'Annotator_172',
#   'Annotator_177',
#   'Annotator_178',
#   'Annotator_183',
#   'Annotator_184',
#   'Annotator_189',
#   'Annotator_190',
#   'Annotator_195',
#   'Annotator_196',
#   'Annotator_201',
#   'Annotator_202',
#   'Annotator_207',
#   'Annotator_208',
#   'Annotator_213',
#   'Annotator_214',
#   'Annotator_219',
#   'Annotator_220',
#   'Annotator_225',
#   'Annotator_226',
#   'Annotator_231',
#   'Annotator_232',
#   'Annotator_237',
#   'Annotator_238',
#   'Annotator_243',
#   'Annotator_244',
#   'Annotator_249',
#   'Annotator_250',
#   'Annotator_255',
#   'Annotator_256',
#   'Annotator_261',
#   'Annotator_262',
#   'Annotator_267',
#   'Annotator_268',
#   'Annotator_273',
#   'Annotator_274',
#   'Annotator_279',
#   'Annotator_280',
#   'Annotator_285',
#   'Annotator_286',
#   'Annotator_291',
#   'Annotator_292',
#   'Annotator_297',
#   'Annotator_298',
#   'Annotator_303',
#   'Annotator_304',
#   'Annotator_309',
#   'Annotator_310',
#   'Annotator_315',
#   'Annotator_316',
#   'Annotator_321',
#   'Annotator_322',
#   'Annotator_327',
#   'Annotator_328',
#   'Annotator_333',
#   'Annotator_334',
#   'Annotator_339',
#   'Annotator_340',
#   'Annotator_345',
#   'Annotator_346',
#   'Annotator_351',
#   'Annotator_352',
#   'Annotator_357',
#   'Annotator_358',
#   'Annotator_363',
#   'Annotator_364',
#   'Annotator_369',
#   'Annotator_370',
#   'Annotator_375',
#   'Annotator_376',
#   'Annotator_381',
#   'Annotator_382',
#   'Annotator_387',
#   'Annotator_388',
#   'Annotator_395',
#   'Annotator_396',
#   'Annotator_401',
#   'Annotator_402',
#   'Annotator_407',
#   'Annotator_408',
#   'Annotator_413',
#   'Annotator_414',
#   'Annotator_419',
#   'Annotator_423',
#   'Annotator_424',
#   'Annotator_429',
#   'Annotator_430',
#   'Annotator_435',
#   'Annotator_436',
#   'Annotator_441',
#   'Annotator_442',
#   'Annotator_447',
#   'Annotator_448',
#   'Annotator_453',
#   'Annotator_454',
#   'Annotator_459',
#   'Annotator_460',
#   'Annotator_465',
#   'Annotator_466',
#   'Annotator_471',
#   'Annotator_472',
#   'Annotator_477',
#   'Annotator_482',
#   'Annotator_483',
#   'Annotator_488',
#   'Annotator_489',
#   'Annotator_494',
#   'Annotator_495',
#   'Annotator_500',
#   'Annotator_501',
#   'Annotator_506',
#   'Annotator_507',
#   'Annotator_512',
#   'Annotator_513',
#   'Annotator_518',
#   'Annotator_519',
#   'Annotator_524',
#   'Annotator_529',
#   'Annotator_530',
#   'Annotator_535',
#   'Annotator_536',
#   'Annotator_541',
#   'Annotator_542',
#   'Annotator_547',
#   'Annotator_548',
#   'Annotator_553',
#   'Annotator_554',
#   'Annotator_559',
#   'Annotator_560',
#   'Annotator_565',
#   'Annotator_566',
#   'Annotator_571',
#   'Annotator_576',
#   'Annotator_577',
#   'Annotator_582',
#   'Annotator_583',
#   'Annotator_588',
#   'Annotator_589',
#   'Annotator_594',
#   'Annotator_595',
#   'Annotator_603',
#   'Annotator_604',
#   'Annotator_609',
#   'Annotator_610',
#   'Annotator_615',
#   'Annotator_616',
#   'Annotator_621',
#   'Annotator_622',
#   'Annotator_627',
#   'Annotator_628',
#   'Annotator_633',
#   'Annotator_634',
#   'Annotator_638',
#   'Annotator_643',
#   'Annotator_644',
#   'Annotator_649',
#   'Annotator_650',
#   'Annotator_655',
#   'Annotator_656',
#   'Annotator_660',
#   'Annotator_661',
#   'Annotator_666',
#   'Annotator_667',
#   'Annotator_672',
#   'Annotator_673',
#   'Annotator_678',
#   'Annotator_679',
#   'Annotator_684',
#   'Annotator_685',
#   'Annotator_689',
#   'Annotator_690',
#   'Annotator_695',
#   'Annotator_696',
#   'Annotator_701',
#   'Annotator_702',
#   'Annotator_707',
#   'Annotator_708',
#   'Annotator_712',
#   'Annotator_713',
#   'Annotator_718',
#   'Annotator_719',
#   'Annotator_724',
#   'Annotator_725']}

# %%
ages = list(Dict_ann_age.keys())
Dict_age_trust = {}
for age in ages:
    sum_trust = np.sum(np.array([Trust_Score[i] for i in Dict_ann_age[age]]))
    Dict_age_trust[age] = sum_trust/len(Dict_ann_age[age])

Dict_age_trust
# Out:
# {'18-22': 0.8485628746393035,
#  '23-45': 0.8551236420540604,
#  '46+': 0.8356457699990758}

# %%
#classify ambiguous tweets
ambiguous_en = ambiguous.loc[ambiguous.lang == 'en']
ambiguous_es = ambiguous.loc[ambiguous.lang == 'es']
ambiguous_en_yes = []
ambiguous_en_no = []
ambiguous_en_neutral = []
for i in range(len(ambiguous_en)):
    yes_score = 0
    no_score = 0
    for j in range(0, len(ambiguous_en.annotators.iloc[i])):
        if ambiguous_en.annotators.iloc[i][j] in Trust_Score:
            if ambiguous_en.labels_task1.iloc[i][j] == 'YES':
                yes_score += Trust_Score[ambiguous_en.annotators.iloc[i][j]]
            else:
                no_score += Trust_Score[ambiguous_en.annotators.iloc[i][j]]
    if yes_score > no_score:
        ambiguous_en_yes.append(ambiguous_en.tweet.iloc[i])
    elif yes_score < no_score:
        ambiguous_en_no.append(ambiguous_en.tweet.iloc[i])
    else:
        ambiguous_en_neutral.append(ambiguous_en.tweet.iloc[i])

print(len(ambiguous_en_yes))
print(len(ambiguous_en_no))
print(len(ambiguous_en_neutral))
# Out:
# 168
# 199
# 23

# %%
print(ambiguous_en_no)
# Out:
# ['‘Making yourself a harder target’ basically boils down to ‘make sure they target someone else’ 🙃 https://t.co/VOpu09YAj6', "I actually had an email from Liz Truss today. She's living the dream. #everydaysexismhttps://t.co/W1YKdKhAu8", 'For yourself of course. Let\'s start with the so called gender pay gap" with a link to an ONS page. This  alone is an example of why feminism is needed. I\'d like to add that out of 164 emoji reactions, only 30 were laughing so it really is an issue #everydaysexism 4/5 https://t.co/J3W3lqD86k', 'Cant believe twitter users harassed mitski because she asked them to not use flash photography at her concerts man i swear to god i hate fifteen year olds when im rich and famous if i see a single phone im breaking it', '@InstagramComms Please #BanAllPornOnInstagram ?There, Are Kids &amp; Teens That Are Being Harassed On, Their Accounts From, Adults Asking For #Sex &amp; #NakedPictures', "@yo_its_simba Here's the link to the full commenthttps://t.co/jyK30AdYqaShe was a trans girl and was harassed a ton for that edited screenshot to the point of deleting the post entirelyI'd suggest deleting this", '@AveryTheComrade I am so happy. Hopefully now he will resign or be expelled. And the women he’s harassed and abused can know he won’t be able to do any more harm', '@EagleAvenging If you know anything about the ever-growing MGTOW movement You know that it is made up of menwho are in their early 30s who refuse to put up with the ups and downs of being in A relationship', '@itsallbollocks @hunkybloodydory We ALL do Steph. It\'s 1.01 black pill, MGTOW incel 21st century "Bro\'s Before Ho\'s" playbook chapter one dating survival guideDON\'T go into DETAIL about the TASTE of the WAAAAAATER. It\'s an Argument Starter!', "@TerfStation @LabelFreeBrands Well, #notallmen. Avoiding your face becoming a baseball glove should be in every man's interest.Bring back the metrosexuals! You can use nice products without being gay or Trans!We mocked the metrosexuals, now look what have", "@BonfireBlaze Why am I still like 'wow, guys STILL publicly say this shit in 2022'??? Clearly there's some small glimmer of hope in me that needs to be quashed immediately. Queue the notallmen brigade🙄", 'Rep. Ayanna Pressley, D-MA, claimed that recent #abortionbans are rooted in a patriarchy and #whitesupremacy. Conservative activist Ryan Girdusky pointed out that nearly all of the nations in Africa ban abortion. "Are they pro-white supremacy?” he asked.', "Also, dump those who tell you that radical love and calm positivity will defeat populist, nostalgic, paternalistic, and strongman politics. A culture shaped by patriarchy and machismo doesn't consider love and positivity masculine or strong. They belong in churches and convents.", '@SusanLynch22 @jgindel @ResisterSis20 @momsbsm1 @Headerop1 @yoksig @jkf3500 @DearAuntCrabby @embeessem @CheckBalance7 @P4boxers @openpodbaydoor_ @ZEphotographic @KendraDrake94 @HickoryFlatG8r @McFaul @skewermann @SuzieBird4 @Suzyqfit4u @LightfootInHwd @katalva3 @HeathenResister Because a bronze age tribal patriarchy is a good model for a modern, technological society, right? https://t.co/Nria61qXiC', "when Pakistani army's go to BTS concert 💜💜💜#weareequal", '@ElleGee36690142 Totally. I keep seeing all the posts about teaching sins not to be abusive, but if a girl comes from a home where she suffers or has witnessed abuse, or doesn’t have a sense of self worth instilled in her then she becomes a target for an abuser.', "@AlexeiRomanov13 @MAIDENHEAD @theresamay @GBNEWS @RTUKnews It's centuries of white western androcentrism. Does this not make you pissed?", "I blame it all on this mfFuck you. Should've been Yukimura. Bitch ass worst 5* in the game. https://t.co/a0PJWxn6uN https://t.co/QsM6ryhXmo", 'Rue ass talked reckless 😭😭😭😭 https://t.co/tmZBC2IOtl', 'i see a girl i think attractive with another guy and start throwing up and crying', '@chilenotsomagic Vesperia is looking very attractive, have it Switch. Looking  ...

# %%
print(ambiguous_en_yes)
# Out:
# ['@GMB this is unacceptable. Use her title as you did for all the men interviewed. She is, in fact, senior to Angus #everydaysexism @TheWomensOrg https://t.co/JZF3a5E4eX', '#EverydaySexism We can &amp; need to do better https://t.co/RePR48B0xv', '@belet_seri @CthuhluRisen You know for a movement that\'s about "hating women" I\'ve seen a lot of support go out to the women who were sexually harrassed and a lot of them call for punishment of those involved, especially the journalists who know and kept it hidden for years even during gamergate', "@AlexVickeryHowe @SteveBoyd0704 @neiljmcevoy @Therumblebear That would matter if anyone was being abused or harassed. But no one was, so it's just yet another bogus claim from a guy with no reliable statistics, research, or proof.Unless you have more bullshit to post, I'll be waiting for your retraction and apology. https://t.co/l7JnSToWxp", 'so dating a man is inherently racist cause you are dating your oppressor? 🤣😂 how do these fuckin idiots think they all got here? a stork dropped them off? lol  you wonder why men subscribe to the idea of MGTOW is because of dumb shits like that far leftist lunatic ..ffs https://t.co/DgFpb8XCKr', 'This is also a very good explanation for why privilege can blind a person to oppressionThey do not feel disadvantaged because the predators/opperssors look/act exactly like they would, &amp; so feel threatened by accusations possibly because they have good intentions e.g #notallmen https://t.co/zDVaQVAXAj', '@kintsugery @dovesummer1 I really liked it! Don’t expect traditional horror - it’s more of a terrifying folk tale. Very atmospheric and a fascinating critique of patriarchy.', 'Always relevant. Fim by Maureen: https://t.co/WgkSweGvln #stopvictimblaming #stopstreetharassment #boos', 'Say it again for the ones in the back! 🗣 When a woman tells you to STFU and stay out her business, you better. 👏🏼 They got too much s**t to deal with, they don’t need yours too! Empower your female friends and put them on a pedestal! They deserve it! #WomensRights #Listen2Her https://t.co/1wBQlQfwLu', '@ABC Media\'s roaring "#WomensRights" BUT EXCEPT voting, #Afghan women MIGHT be more protected by their gov or by the #Taliban (Let\'s wait &amp; see) than US &amp; #FrenchWomen. Remember how many lies they told about #Lybia. TV &amp; films show us only radical foreigners. @BlackQueenLara\'s right.', "Dear Supreme Court and @GOP If you don't know me, you don't get to decide my medical decisions #SupremeCourt #WomensRights", '@jefaesthetics @KMPHFOX26 Completely agree!!! 🙌#shameontexas #abortionrights #WomensRights', '@Stephenkek101 @rockin1mom @mcasper10 @Houston4Warren @SenTinaSmith Didn’t you try a day without women a few years back and no one noticed?', '@miaeranasimp @ctrlfantasy LMAO, baby girl. You wouldn’t go a day without women ❤️', "@TheRealHoarse To hell with a day without women it's time for every woman in the US to go on vacation until we are treated equal under the law and useless pathetic men stop sticking thier noses where it doesn't belong.", '@Stanikzaiii @natiqmalikzada Even without TTP the women have many problems. I feel pity for this girl as she can only speak English but unable to see the discrimination, patriarchy, misogyny and androcentrism. She needs sensitization program.', '"Men and women should be equal. Why do you always think I\'m not as good as a man?" that slap and changge\'s tears tho#WeTVawards2021XDilraba#TheLongBallad https://t.co/p9oFVEPuFk', "@RJBurner9000 @peacebang Dude I use a Hitachi wand semi-regularly and can still say I'm never disappointed when my husband goes down on me or uses his hands. It's a different sensation entirely, and sure sometimes it's faster with the wand, but it doesn't feel nearly as good as a man who listens.", '@mtgreenee congress men and woman are allowing the mandates to continue .. women fought for male roles in the army and can now do all those jobs . part of those jobs is selective service .. can’t sometimes  ...

# %%
print(ambiguous_en_neutral)
